# %%
import sys
sys.path.append('../src')
from utils import dag_utils 
from show.model import brasil_model
from show.model import worl_model
import requests
import json

# %% [markdown]
# ## Get Brasil e World Model

# %%
brasil = brasil_model.BrasilDada(config_data_path='..')
#world = worl_model.WorldHealth(config_data_path='..')
brasil_data = brasil.db
#world_data = world.db
# Out:
# ..

# %% [markdown]
# ### Interiorização

# %% [markdown]
# **Pegando obitos**

# %%
city = 'SP'
place_type = 'state'

# %%
query = f"SELECT date,sum(new_deaths) as deaths FROM casos_full WHERE {place_type} = '{city}' group by(date)"
df_estado = brasil_data.execute_query(query)
df_estado.head()
# Out:
# ../config/data_config.yaml
#          date  deaths
# 0  2020-02-25     0.0
# 1  2020-02-26     0.0
# 2  2020-02-27     0.0
# 3  2020-02-28     0.0
# 4  2020-02-29     0.0

# %% [markdown]
# **Pegados dados da cidade**

# %%
place_type = 'state'
city = 'SP'

query = f"SELECT * FROM casos_full WHERE {place_type} = '{city}'"
df_cidades = brasil_data.execute_query(query)
df_cidades.head()

#data_dict
link = f'https://servicodados.ibge.gov.br/api/v1/localidades/estados/{city}/distritos'
data_dict = requests.get(link).json()

city_dict = {}
for data_cidade in data_dict:
    cidade = data_cidade['municipio']['nome']
    regiao = data_cidade['municipio']['microrregiao']['mesorregiao']['nome']
    city_dict[cidade] = regiao

def set_tipo_regiao(cidade):
    if cidade in city_dict and 'Metropolitana' in city_dict[cidade]:
        return 'capital' 
    else:
        return 'interior'
# Out:
# ../config/data_config.yaml

# %% [markdown]
# **comparar capital e interior**

# %%
df_cidades['tipo_reg'] = df_cidades['city'].apply(set_tipo_regiao)

# %%
df_cidades.groupby('tipo_reg').sum()['new_deaths']
# Out:
# tipo_reg
# capital     14872
# interior    21359
# Name: new_deaths, dtype: int64

# %% [markdown]
# **Grafico temporal**

# %%
import matplotlib.pyplot as plt

# %%
interior = df_cidades[df_cidades['tipo_reg'] == 'interior']
interior_date = interior.groupby('date').sum()['new_deaths']
interior_date.index = pd.to_datetime(interior_date.index)

capital = df_cidades[df_cidades['tipo_reg'] == 'capital']
capital_date = capital.groupby('date').sum()['new_deaths']
capital_date.index = pd.to_datetime(capital_date.index)

# %%
interior_date.plot(label='interior')
capital_date.plot(label='capital')
plt.legend()

# %%
interior_date.groupby(pd.Grouper(freq='w')).mean().plot(label='interior')
capital_date.groupby(pd.Grouper(freq='w')).mean().plot(label='capital')
plt.legend()

# %% [markdown]
# ## Ajuda

# %% [markdown]
# **Verificando região po municipio**

# %%
state = 'SP'

# %%
data_dict = requests.get(link).json()

# %%
data_dict
# Out:
# [{'id': 350010505,
#   'nome': 'Adamantina',
#   'municipio': {'id': 3500105,
#    'nome': 'Adamantina',
#    'microrregiao': {'id': 35035,
#     'nome': 'Adamantina',
#     'mesorregiao': {'id': 3508,
#      'nome': 'Presidente Prudente',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350020405,
#   'nome': 'Adolfo',
#   'municipio': {'id': 3500204,
#    'nome': 'Adolfo',
#    'microrregiao': {'id': 35004,
#     'nome': 'São José do Rio Preto',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350030305,
#   'nome': 'Aguaí',
#   'municipio': {'id': 3500303,
#    'nome': 'Aguaí',
#    'microrregiao': {'id': 35029,
#     'nome': 'Pirassununga',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350040205,
#   'nome': 'Águas da Prata',
#   'municipio': {'id': 3500402,
#    'nome': 'Águas da Prata',
#    'microrregiao': {'id': 35030,
#     'nome': 'São João da Boa Vista',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350040210,
#   'nome': 'São Roque da Fartura',
#   'municipio': {'id': 3500402,
#    'nome': 'Águas da Prata',
#    'microrregiao': {'id': 35030,
#     'nome': 'São João da Boa Vista',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350050105,
#   'nome': 'Águas de Lindóia',
#   'municipio': {'id': 3500501,
#    'nome': 'Águas de Lindóia',
#    'microrregiao': {'id': 35033,
#     'nome': 'Amparo',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350055005,
#   'nome': 'Águas de Santa Bárbara',
#   'municipio': {'id': 3500550,
#    'nome': 'Águas de Santa Bárbara',
#    'microrregiao': {'id': 35022,
#     'nome': 'Avaré',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350060005,
#   'nome': 'Águas de São Pedro',
#   'municipio': {'id': 3500600,
#    'nome': 'Águas de São Pedro',
#    'microrregiao': {'id': 35028,
#     'nome': 'Piracicaba',
#     'mesorregiao': {'id': 3506,
#      'nome': 'Piracicaba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350070905,
#   'nome': 'Agudos',
#   'municipio': {'id': 3500709,
#    'nome': 'Agudos',
#    'microrregiao': {'id': 35020,
#     'nome': 'Bauru',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350070910,
#   'nome': 'Domélia',
#   'municipio': {'id': 3500709,
#    'nome': 'Agudos',
#    'microrregiao': {'id': 35020,
#     'nome': 'Bauru',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350075805,
#   'nome': 'Alambari',
#   'municipio': {'id': 3500758,
#    'nome': 'Alambari',
#    'microrregiao': {'id': 35042,
#     'nome': 'Itapetininga',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350080805,
#   'nome': 'Alfredo Marcondes',
#   'municipio': {'id': 3500808,
#    'nome': 'Alfredo Marcondes',
#    'microrregiao': {'id': 35036,
#     'nome': 'Presidente Prudente',
#     'mesorregiao': {'id': 3508,
#      'nome': 'Presidente Prudente',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350090705,
#   'nome': 'Altair',
#   'municipio': {'id': 3500907,
#    'nome': 'Altair',
#    'microrregiao': {'id': 35004,
#     'nome': 'São José do Rio Preto',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350090715,
#   'nome': 'Suinana',
#   'municipio': {'id': 3500907,
#    'nome': 'Altair',
#    'microrregiao': {'id': 35004,
#     'nome': 'São José do Rio Preto',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350100405,
#   'nome': 'Altinópolis',
#   'municipio': {'id': 3501004,
#    'nome': 'Altinópolis',
#    'microrregiao': {'id': 35015,
#     'nome': 'Batatais',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350110305,
#   'nome': 'Alto Alegre',
#   'municipio': {'id': 3501103,
#    'nome': 'Alto Alegre',
#    'microrregiao': {'id': 35018,
#     'nome': 'Birigui',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350110310,
#   'nome': 'Jatobá',
#   'municipio': {'id': 3501103,
#    'nome': 'Alto Alegre',
#    'microrregiao': {'id': 35018,
#     'nome': 'Birigui',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350110315,
#   'nome': "São Martinho d'Oeste",
#   'municipio': {'id': 3501103,
#    'nome': 'Alto Alegre',
#    'microrregiao': {'id': 35018,
#     'nome': 'Birigui',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350115205,
#   'nome': 'Alumínio',
#   'municipio': {'id': 3501152,
#    'nome': 'Alumínio',
#    'microrregiao': {'id': 35046,
#     'nome': 'Sorocaba',
#     'mesorregiao': {'id': 3512,
#      'nome': 'Macro Metropolitana Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350120205,
#   'nome': 'Álvares Florence',
#   'municipio': {'id': 3501202,
#    'nome': 'Álvares Florence',
#    'microrregiao': {'id': 35003,
#     'nome': 'Votuporanga',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350120210,
#   'nome': 'Boa Vista dos Andradas',
#   'municipio': {'id': 3501202,
#    'nome': 'Álvares Florence',
#    'microrregiao': {'id': 35003,
#     'nome': 'Votuporanga',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350130105,
#   'nome': 'Álvares Machado',
#   'municipio': {'id': 3501301,
#    'nome': 'Álvares Machado',
#    'microrregiao': {'id': 35036,
#     'nome': 'Presidente Prudente',
#     'mesorregiao': {'id': 3508,
#      'nome': 'Presidente Prudente',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350130110,
#   'nome': 'Coronel Goulart',
#   'municipio': {'id': 3501301,
#    'nome': 'Álvares Machado',
#    'microrregiao': {'id': 35036,
#     'nome': 'Presidente Prudente',
#     'mesorregiao': {'id': 3508,
#      'nome': 'Presidente Prudente',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350140005,
#   'nome': 'Álvaro de Carvalho',
#   'municipio': {'id': 3501400,
#    'nome': 'Álvaro de Carvalho',
#    'microrregiao': {'id': 35038,
#     'nome': 'Marília',
#     'mesorregiao': {'id': 3509,
#      'nome': 'Marília',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350150905,
#   'nome': 'Alvinlândia',
#   'municipio': {'id': 3501509,
#    'nome': 'Alvinlândia',
#    'microrregiao': {'id': 35038,
#     'nome': 'Marília',
#     'mesorregiao': {'id': 3509,
#      'nome': 'Marília',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350160805,
#   'nome': 'Americana',
#   'municipio': {'id': 3501608,
#    'nome': 'Americana',
#    'microrregiao': {'id': 35032,
#     'nome': 'Campinas',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350170705,
#   'nome': 'Américo Brasiliense',
#   'municipio': {'id': 3501707,
#    'nome': 'Américo Brasiliense',
#    'microrregiao': {'id': 35024,
#     'nome': 'Araraquara',
#     'mesorregiao': {'id': 3505,
#      'nome': 'Araraquara',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350180605,
#   'nome': 'Américo de Campos',
#   'municipio': {'id': 3501806,
#    'nome': 'Américo de Campos',
#    'microrregiao': {'id': 35003,
#     'nome': 'Votuporanga',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350190505,
#   'nome': 'Amparo',
#   'municipio': {'id': 3501905,
#    'nome': 'Amparo',
#    'microrregiao': {'id': 35033,
#     'nome': 'Amparo',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350190510,
#   'nome': 'Arcadas',
#   'municipio': {'id': 3501905,
#    'nome': 'Amparo',
#    'microrregiao': {'id': 35033,
#     'nome': 'Amparo',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350190515,
#   'nome': 'Três Pontes',
#   'municipio': {'id': 3501905,
#    'nome': 'Amparo',
#    'microrregiao': {'id': 35033,
#     'nome': 'Amparo',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350200205,
#   'nome': 'Analândia',
#   'municipio': {'id': 3502002,
#    'nome': 'Analândia',
#    'microrregiao': {'id': 35025,
#     'nome': 'São Carlos',
#     'mesorregiao': {'id': 3505,
#      'nome': 'Araraquara',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350210105,
#   'nome': 'Andradina',
#   'municipio': {'id': 3502101,
#    'nome': 'Andradina',
#    'microrregiao': {'id': 35016,
#     'nome': 'Andradina',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350220005,
#   'nome': 'Angatuba',
#   'municipio': {'id': 3502200,
#    'nome': 'Angatuba',
#    'microrregiao': {'id': 35042,
#     'nome': 'Itapetininga',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350220008,
#   'nome': 'Bom Retiro da Esperança',
#   'municipio': {'id': 3502200,
#    'nome': 'Angatuba',
#    'microrregiao': {'id': 35042,
#     'nome': 'Itapetininga',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350230905,
#   'nome': 'Anhembi',
#   'municipio': {'id': 3502309,
#    'nome': 'Anhembi',
#    'microrregiao': {'id': 35023,
#     'nome': 'Botucatu',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350230910,
#   'nome': 'Pirambóia',
#   'municipio': {'id': 3502309,
#    'nome': 'Anhembi',
#    'microrregiao': {'id': 35023,
#     'nome': 'Botucatu',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350240805,
#   'nome': 'Anhumas',
#   'municipio': {'id': 3502408,
#    'nome': 'Anhumas',
#    'microrregiao': {'id': 35036,
#     'nome': 'Presidente Prudente',
#     'mesorregiao': {'id': 3508,
#      'nome': 'Presidente Prudente',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350250705,
#   'nome': 'Aparecida',
#   'municipio': {'id': 3502507,
#    'nome': 'Aparecida',
#    'microrregiao': {'id': 35051,
#     'nome': 'Guaratinguetá',
#     'mesorregiao': {'id': 3513,
#      'nome': 'Vale do Paraíba Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350260605,
#   'nome': "Aparecida d'Oeste",
#   'municipio': {'id': 3502606,
#    'nome': "Aparecida d'Oeste",
#    'microrregiao': {'id': 35001,
#     'nome': 'Jales',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350270505,
#   'nome': 'Apiaí',
#   'municipio': {'id': 3502705,
#    'nome': 'Apiaí',
#    'microrregiao': {'id': 35044,
#     'nome': 'Capão Bonito',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350270510,
#   'nome': 'Araçaíba',
#   'municipio': {'id': 3502705,
#    'nome': 'Apiaí',
#    'microrregiao': {'id': 35044,
#     'nome': 'Capão Bonito',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350270525,
#   'nome': 'Lageado de Araçaíba',
#   'municipio': {'id': 3502705,
#    'nome': 'Apiaí',
#    'microrregiao': {'id': 35044,
#     'nome': 'Capão Bonito',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350270530,
#   'nome': 'Palmitalzinho',
#   'municipio': {'id': 3502705,
#    'nome': 'Apiaí',
#    'microrregiao': {'id': 35044,
#     'nome': 'Capão Bonito',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350275405,
#   'nome': 'Araçariguama',
#   'municipio': {'id': 3502754,
#    'nome': 'Araçariguama',
#    'microrregiao': {'id': 35046,
#     'nome': 'Sorocaba',
#     'mesorregiao': {'id': 3512,
#      'nome': 'Macro Metropolitana Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350280405,
#   'nome': 'Araçatuba',
#   'municipio': {'id': 3502804,
#    'nome': 'Araçatuba',
#    'microrregiao': {'id': 35017,
#     'nome': 'Araçatuba',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350290305,
#   'nome': 'Araçoiaba da Serra',
#   'municipio': {'id': 3502903,
#    'nome': 'Araçoiaba da Serra',
#    'microrregiao': {'id': 35046,
#     'nome': 'Sorocaba',
#     'mesorregiao': {'id': 3512,
#      'nome': 'Macro Metropolitana Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350300005,
#   'nome': 'Aramina',
#   'municipio': {'id': 3503000,
#    'nome': 'Aramina',
#    'microrregiao': {'id': 35011,
#     'nome': 'Ituverava',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350310905,
#   'nome': 'Arandu',
#   'municipio': {'id': 3503109,
#    'nome': 'Arandu',
#    'microrregiao': {'id': 35022,
#     'nome': 'Avaré',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350315805,
#   'nome': 'Arapeí',
#   'municipio': {'id': 3503158,
#    'nome': 'Arapeí',
#    'microrregiao': {'id': 35052,
#     'nome': 'Bananal',
#     'mesorregiao': {'id': 3513,
#      'nome': 'Vale do Paraíba Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350320805,
#   'nome': 'Araraquara',
#   'municipio': {'id': 3503208,
#    'nome': 'Araraquara',
#    'microrregiao': {'id': 35024,
#     'nome': 'Araraquara',
#     'mesorregiao': {'id': 3505,
#      'nome': 'Araraquara',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350320810,
#   'nome': 'Bueno de Andrada',
#   'municipio': {'id': 3503208,
#    'nome': 'Araraquara',
#    'microrregiao': {'id': 35024,
#     'nome': 'Araraquara',
#     'mesorregiao': {'id': 3505,
#      'nome': 'Araraquara',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350320825,
#   'nome': 'Vila Xavier',
#   'municipio': {'id': 3503208,
#    'nome': 'Araraquara',
#    'microrregiao': {'id': 35024,
#     'nome': 'Araraquara',
#     'mesorregiao': {'id': 3505,
#      'nome': 'Araraquara',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350330705,
#   'nome': 'Araras',
#   'municipio': {'id': 3503307,
#    'nome': 'Araras',
#    'microrregiao': {'id': 35027,
#     'nome': 'Limeira',
#     'mesorregiao': {'id': 3506,
#      'nome': 'Piracicaba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350335605,
#   'nome': 'Arco-Íris',
#   'municipio': {'id': 3503356,
#    'nome': 'Arco-Íris',
#    'microrregiao': {'id': 35037,
#     'nome': 'Tupã',
#     'mesorregiao': {'id': 3509,
#      'nome': 'Marília',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350340605,
#   'nome': 'Arealva',
#   'municipio': {'id': 3503406,
#    'nome': 'Arealva',
#    'microrregiao': {'id': 35020,
#     'nome': 'Bauru',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350340610,
#   'nome': 'Jacuba',
#   'municipio': {'id': 3503406,
#    'nome': 'Arealva',
#    'microrregiao': {'id': 35020,
#     'nome': 'Bauru',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350350505,
#   'nome': 'Areias',
#   'municipio': {'id': 3503505,
#    'nome': 'Areias',
#    'microrregiao': {'id': 35052,
#     'nome': 'Bananal',
#     'mesorregiao': {'id': 3513,
#      'nome': 'Vale do Paraíba Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350360405,
#   'nome': 'Areiópolis',
#   'municipio': {'id': 3503604,
#    'nome': 'Areiópolis',
#    'microrregiao': {'id': 35020,
#     'nome': 'Bauru',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350370305,
#   'nome': 'Ariranha',
#   'municipio': {'id': 3503703,
#    'nome': 'Ariranha',
#    'microrregiao': {'id': 35005,
#     'nome': 'Catanduva',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350380205,
#   'nome': 'Artur Nogueira',
#   'municipio': {'id': 3503802,
#    'nome': 'Artur Nogueira',
#    'microrregiao': {'id': 35031,
#     'nome': 'Mogi Mirim',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350390105,
#   'nome': 'Arujá',
#   'municipio': {'id': 3503901,
#    'nome': 'Arujá',
#    'microrregiao': {'id': 35059,
#     'nome': 'Guarulhos',
#     'mesorregiao': {'id': 3515,
#      'nome': 'Metropolitana de São Paulo',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350395005,
#   'nome': 'Aspásia',
#   'municipio': {'id': 3503950,
#    'nome': 'Aspásia',
#    'microrregiao': {'id': 35001,
#     'nome': 'Jales',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350400805,
#   'nome': 'Assis',
#   'municipio': {'id': 3504008,
#    'nome': 'Assis',
#    'microrregiao': {'id': 35039,
#     'nome': 'Assis',
#     'mesorregiao': {'id': 3510,
#      'nome': 'Assis',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350410705,
#   'nome': 'Atibaia',
#   'municipio': {'id': 3504107,
#    'nome': 'Atibaia',
#    'microrregiao': {'id': 35048,
#     'nome': 'Bragança Paulista',
#     'mesorregiao': {'id': 3512,
#      'nome': 'Macro Metropolitana Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350420605,
#   'nome': 'Auriflama',
#   'municipio': {'id': 3504206,
#    'nome': 'Auriflama',
#    'microrregiao': {'id': 35006,
#     'nome': 'Auriflama',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350430505,
#   'nome': 'Avaí',
#   'municipio': {'id': 3504305,
#    'nome': 'Avaí',
#    'microrregiao': {'id': 35020,
#     'nome': 'Bauru',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350430510,
#   'nome': 'Nogueira',
#   'municipio': {'id': 3504305,
#    'nome': 'Avaí',
#    'microrregiao': {'id': 35020,
#     'nome': 'Bauru',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350440405,
#   'nome': 'Avanhandava',
#   'municipio': {'id': 3504404,
#    'nome': 'Avanhandava',
#    'microrregiao': {'id': 35018,
#     'nome': 'Birigui',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350450305,
#   'nome': 'Avaré',
#   'municipio': {'id': 3504503,
#    'nome': 'Avaré',
#    'microrregiao': {'id': 35022,
#     'nome': 'Avaré',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350460205,
#   'nome': 'Bady Bassitt',
#   'municipio': {'id': 3504602,
#    'nome': 'Bady Bassitt',
#    'microrregiao': {'id': 35004,
#     'nome': 'São José do Rio Preto',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350470105,
#   'nome': 'Balbinos',
#   'municipio': {'id': 3504701,
#    'nome': 'Balbinos',
#    'microrregiao': {'id': 35020,
#     'nome': 'Bauru',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350480005,
#   'nome': 'Bálsamo',
#   'municipio': {'id': 3504800,
#    'nome': 'Bálsamo',
#    'microrregiao': {'id': 35004,
#     'nome': 'São José do Rio Preto',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350490905,
#   'nome': 'Bananal',
#   'municipio': {'id': 3504909,
#    'nome': 'Bananal',
#    'microrregiao': {'id': 35052,
#     'nome': 'Bananal',
#     'mesorregiao': {'id': 3513,
#      'nome': 'Vale do Paraíba Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350500505,
#   'nome': 'Barão de Antonina',
#   'municipio': {'id': 3505005,
#    'nome': 'Barão de Antonina',
#    'microrregiao': {'id': 35041,
#     'nome': 'Itapeva',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350510405,
#   'nome': 'Barbosa',
#   'municipio': {'id': 3505104,
#    'nome': 'Barbosa',
#    'microrregiao': {'id': 35018,
#     'nome': 'Birigui',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350520305,
#   'nome': 'Bariri',
#   'municipio': {'id': 3505203,
#    'nome': 'Bariri',
#    'microrregiao': {'id': 35021,
#     'nome': 'Jaú',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350530205,
#   'nome': 'Barra Bonita',
#   'municipio': {'id': 3505302,
#    'nome': 'Barra Bonita',
#    'microrregiao': {'id': 35021,
#     'nome': 'Jaú',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350535105,
#   'nome': 'Barra do Chapéu',
#   'municipio': {'id': 3505351,
#    'nome': 'Barra do Chapéu',
#    'microrregiao': {'id': 35044,
#     'nome': 'Capão Bonito',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350540105,
#   'nome': 'Barra do Turvo',
#   'municipio': {'id': 3505401,
#    'nome': 'Barra do Turvo',
#    'microrregiao': {'id': 35055,
#     'nome': 'Registro',
#     'mesorregiao': {'id': 3514,
#      'nome': 'Litoral Sul Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350550005,
#   'nome': 'Barretos',
#   'municipio': {'id': 3505500,
#    'nome': 'Barretos',
#    'microrregiao': {'id': 35009,
#     'nome': 'Barretos',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350550010,
#   'nome': 'Alberto Moreira',
#   'municipio': {'id': 3505500,
#    'nome': 'Barretos',
#    'microrregiao': {'id': 35009,
#     'nome': 'Barretos',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350550015,
#   'nome': 'Ibitu',
#   'municipio': {'id': 3505500,
#    'nome': 'Barretos',
#    'microrregiao': {'id': 35009,
#     'nome': 'Barretos',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350560905,
#   'nome': 'Barrinha',
#   'municipio': {'id': 3505609,
#    'nome': 'Barrinha',
#    'microrregiao': {'id': 35014,
#     'nome': 'Ribeirão Preto',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350570805,
#   'nome': 'Barueri',
#   'municipio': {'id': 3505708,
#    'nome': 'Barueri',
#    'microrregiao': {'id': 35057,
#     'nome': 'Osasco',
#     'mesorregiao': {'id': 3515,
#      'nome': 'Metropolitana de São Paulo',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350570810,
#   'nome': 'Aldeia',
#   'municipio': {'id': 3505708,
#    'nome': 'Barueri',
#    'microrregiao': {'id': 35057,
#     'nome': 'Osasco',
#     'mesorregiao': {'id': 3515,
#      'nome': 'Metropolitana de São Paulo',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350570815,
#   'nome': 'Jardim Belval',
#   'municipio': {'id': 3505708,
#    'nome': 'Barueri',
#    'microrregiao': {'id': 35057,
#     'nome': 'Osasco',
#     'mesorregiao': {'id': 3515,
#      'nome': 'Metropolitana de São Paulo',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350570820,
#   'nome': 'Jardim Silveira',
#   'municipio': {'id': 3505708,
#    'nome': 'Barueri',
#    'microrregiao': {'id': 35057,
#     'nome': 'Osasco',
#     'mesorregiao': {'id': 3515,
#      'nome': 'Metropolitana de São Paulo',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350580705,
#   'nome': 'Bastos',
#   'municipio': {'id': 3505807,
#    'nome': 'Bastos',
#    'microrregiao': {'id': 35037,
#     'nome': 'Tupã',
#     'mesorregiao': {'id': 3509,
#      'nome': 'Marília',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350590605,
#   'nome': 'Batatais',
#   'municipio': {'id': 3505906,
#    'nome': 'Batatais',
#    'microrregiao': {'id': 35015,
#     'nome': 'Batatais',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350600305,
#   'nome': 'Bauru',
#   'municipio': {'id': 3506003,
#    'nome': 'Bauru',
#    'microrregiao': {'id': 35020,
#     'nome': 'Bauru',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350600310,
#   'nome': 'Tibiriçá',
#   'municipio': {'id': 3506003,
#    'nome': 'Bauru',
#    'microrregiao': {'id': 35020,
#     'nome': 'Bauru',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350610205,
#   'nome': 'Bebedouro',
#   'municipio': {'id': 3506102,
#    'nome': 'Bebedouro',
#    'microrregiao': {'id': 35013,
#     'nome': 'Jaboticabal',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350610210,
#   'nome': 'Botafogo',
#   'municipio': {'id': 3506102,
#    'nome': 'Bebedouro',
#    'microrregiao': {'id': 35013,
#     'nome': 'Jaboticabal',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350610215,
#   'nome': 'Turvínia',
#   'municipio': {'id': 3506102,
#    'nome': 'Bebedouro',
#    'microrregiao': {'id': 35013,
#     'nome': 'Jaboticabal',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350620105,
#   'nome': 'Bento de Abreu',
#   'municipio': {'id': 3506201,
#    'nome': 'Bento de Abreu',
#    'microrregiao': {'id': 35017,
#     'nome': 'Araçatuba',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350630005,
#   'nome': 'Bernardino de Campos',
#   'municipio': {'id': 3506300,
#    'nome': 'Bernardino de Campos',
#    'microrregiao': {'id': 35040,
#     'nome': 'Ourinhos',
#     'mesorregiao': {'id': 3510,
#      'nome': 'Assis',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350635905,
#   'nome': 'Bertioga',
#   'municipio': {'id': 3506359,
#    'nome': 'Bertioga',
#    'microrregiao': {'id': 35063,
#     'nome': 'Santos',
#     'mesorregiao': {'id': 3515,
#      'nome': 'Metropolitana de São Paulo',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350640905,
#   'nome': 'Bilac',
#   'municipio': {'id': 3506409,
#    'nome': 'Bilac',
#    'microrregiao': {'id': 35018,
#     'nome': 'Birigui',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350650805,
#   'nome': 'Birigui',
#   'municipio': {'id': 3506508,
#    'nome': 'Birigui',
#    'microrregiao': {'id': 35018,
#     'nome': 'Birigui',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350660705,
#   'nome': 'Biritiba Mirim',
#   'municipio': {'id': 3506607,
#    'nome': 'Biritiba Mirim',
#    'microrregiao': {'id': 35062,
#     'nome': 'Mogi das Cruzes',
#     'mesorregiao': {'id': 3515,
#      'nome': 'Metropolitana de São Paulo',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350670605,
#   'nome': 'Boa Esperança do Sul',
#   'municipio': {'id': 3506706,
#    'nome': 'Boa Esperança do Sul',
#    'microrregiao': {'id': 35024,
#     'nome': 'Araraquara',
#     'mesorregiao': {'id': 3505,
#      'nome': 'Araraquara',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350680505,
#   'nome': 'Bocaina',
#   'municipio': {'id': 3506805,
#    'nome': 'Bocaina',
#    'microrregiao': {'id': 35021,
#     'nome': 'Jaú',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350690405,
#   'nome': 'Bofete',
#   'municipio': {'id': 3506904,
#    'nome': 'Bofete',
#    'microrregiao': {'id': 35023,
#     'nome': 'Botucatu',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350690410,
#   'nome': 'São Roque Novo',
#   'municipio': {'id': 3506904,
#    'nome': 'Bofete',
#    'microrregiao': {'id': 35023,
#     'nome': 'Botucatu',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350700105,
#   'nome': 'Boituva',
#   'municipio': {'id': 3507001,
#    'nome': 'Boituva',
#    'microrregiao': {'id': 35043,
#     'nome': 'Tatuí',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350710005,
#   'nome': 'Bom Jesus dos Perdões',
#   'municipio': {'id': 3507100,
#    'nome': 'Bom Jesus dos Perdões',
#    'microrregiao': {'id': 35048,
#     'nome': 'Bragança Paulista',
#     'mesorregiao': {'id': 3512,
#      'nome': 'Macro Metropolitana Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350715905,
#   'nome': 'Bom Sucesso de Itararé',
#   'municipio': {'id': 3507159,
#    'nome': 'Bom Sucesso de Itararé',
#    'microrregiao': {'id': 35041,
#     'nome': 'Itapeva',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350720905,
#   'nome': 'Borá',
#   'municipio': {'id': 3507209,
#    'nome': 'Borá',
#    'microrregiao': {'id': 35039,
#     'nome': 'Assis',
#     'mesorregiao': {'id': 3510,
#      'nome': 'Assis',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350730805,
#   'nome': 'Boracéia',
#   'municipio': {'id': 3507308,
#    'nome': 'Boracéia',
#    'microrregiao': {'id': 35021,
#     'nome': 'Jaú',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350740705,
#   'nome': 'Borborema',
#   'municipio': {'id': 3507407,
#    'nome': 'Borborema',
#    'microrregiao': {'id': 35024,
#     'nome': 'Araraquara',
#     'mesorregiao': {'id': 3505,
#      'nome': 'Araraquara',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350745605,
#   'nome': 'Borebi',
#   'municipio': {'id': 3507456,
#    'nome': 'Borebi',
#    'microrregiao': {'id': 35020,
#     'nome': 'Bauru',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350750605,
#   'nome': 'Botucatu',
#   'municipio': {'id': 3507506,
#    'nome': 'Botucatu',
#    'microrregiao': {'id': 35023,
#     'nome': 'Botucatu',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350750610,
#   'nome': 'Rubião Júnior',
#   'municipio': {'id': 3507506,
#    'nome': 'Botucatu',
#    'microrregiao': {'id': 35023,
#     'nome': 'Botucatu',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350750615,
#   'nome': 'Vitoriana',
#   'municipio': {'id': 3507506,
#    'nome': 'Botucatu',
#    'microrregiao': {'id': 35023,
#     'nome': 'Botucatu',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350760505,
#   'nome': 'Bragança Paulista',
#   'municipio': {'id': 3507605,
#    'nome': 'Bragança Paulista',
#    'microrregiao': {'id': 35048,
#     'nome': 'Bragança Paulista',
#     'mesorregiao': {'id': 3512,
#      'nome': 'Macro Metropolitana Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350770405,
#   'nome': 'Braúna',
#   'municipio': {'id': 3507704,
#    'nome': 'Braúna',
#    'microrregiao': {'id': 35018,
#     'nome': 'Birigui',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350775305,
#   'nome': 'Brejo Alegre',
#   'municipio': {'id': 3507753,
#    'nome': 'Brejo Alegre',
#    'microrregiao': {'id': 35018,
#     'nome': 'Birigui',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350780305,
#   'nome': 'Brodowski',
#   'municipio': {'id': 3507803,
#    'nome': 'Brodowski',
#    'microrregiao': {'id': 35014,
#     'nome': 'Ribeirão Preto',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350790205,
#   'nome': 'Brotas',
#   'municipio': {'id': 3507902,
#    'nome': 'Brotas',
#    'microrregiao': {'id': 35026,
#     'nome': 'Rio Claro',
#     'mesorregiao': {'id': 3506,
#      'nome': 'Piracicaba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350790210,
#   'nome': 'São Sebastião da Serra',
#   'municipio': {'id': 3507902,
#    'nome': 'Brotas',
#    'microrregiao': {'id': 35026,
#     'nome': 'Rio Claro',
#     'mesorregiao': {'id': 3506,
#      'nome': 'Piracicaba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350800905,
#   'nome': 'Buri',
#   'municipio': {'id': 3508009,
#    'nome': 'Buri',
#    'microrregiao': {'id': 35041,
#     'nome': 'Itapeva',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350800910,
#   'nome': 'Aracaçu',
#   'municipio': {'id': 3508009,
#    'nome': 'Buri',
#    'microrregiao': {'id': 35041,
#     'nome': 'Itapeva',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350810805,
#   'nome': 'Buritama',
#   'municipio': {'id': 3508108,
#    'nome': 'Buritama',
#    'microrregiao': {'id': 35018,
#     'nome': 'Birigui',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350820705,
#   'nome': 'Buritizal',
#   'municipio': {'id': 3508207,
#    'nome': 'Buritizal',
#    'microrregiao': {'id': 35011,
#     'nome': 'Ituverava',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350830605,
#   'nome': 'Cabrália Paulista',
#   'municipio': {'id': 3508306,
#    'nome': 'Cabrália Paulista',
#    'microrregiao': {'id': 35020,
#     'nome': 'Bauru',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350840505,
#   'nome': 'Cabreúva',
#   'municipio': {'id': 3508405,
#    'nome': 'Cabreúva',
#    'microrregiao': {'id': 35046,
#     'nome': 'Sorocaba',
#     'mesorregiao': {'id': 3512,
#      'nome': 'Macro Metropolitana Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350840510,
#   'nome': 'Bom Fim do Bom Jesus',
#   'municipio': {'id': 3508405,
#    'nome': 'Cabreúva',
#    'microrregiao': {'id': 35046,
#     'nome': 'Sorocaba',
#     'mesorregiao': {'id': 3512,
#      'nome': 'Macro Metropolitana Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350840520,
#   'nome': 'Jacaré',
#   'municipio': {'id': 3508405,
#    'nome': 'Cabreúva',
#    'microrregiao': {'id': 35046,
#     'nome': 'Sorocaba',
#     'mesorregiao': {'id': 3512,
#      'nome': 'Macro Metropolitana Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350850405,
#   'nome': 'Caçapava',
#   'municipio': {'id': 3508504,
#    'nome': 'Caçapava',
#    'microrregiao': {'id': 35050,
#     'nome': 'São José dos Campos',
#     'mesorregiao': {'id': 3513,
#      'nome': 'Vale do Paraíba Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350860305,
#   'nome': 'Cachoeira Paulista',
#   'municipio': {'id': 3508603,
#    'nome': 'Cachoeira Paulista',
#    'microrregiao': {'id': 35051,
#     'nome': 'Guaratinguetá',
#     'mesorregiao': {'id': 3513,
#      'nome': 'Vale do Paraíba Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350870205,
#   'nome': 'Caconde',
#   'municipio': {'id': 3508702,
#    'nome': 'Caconde',
#    'microrregiao': {'id': 35030,
#     'nome': 'São João da Boa Vista',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350870210,
#   'nome': 'Barrânia',
#   'municipio': {'id': 3508702,
#    'nome': 'Caconde',
#    'microrregiao': {'id': 35030,
#     'nome': 'São João da Boa Vista',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350880105,
#   'nome': 'Cafelândia',
#   'municipio': {'id': 3508801,
#    'nome': 'Cafelândia',
#    'microrregiao': {'id': 35019,
#     'nome': 'Lins',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350880110,
#   'nome': 'Bacuriti',
#   'municipio': {'id': 3508801,
#    'nome': 'Cafelândia',
#    'microrregiao': {'id': 35019,
#     'nome': 'Lins',
#     'mesorregiao': {'id': 3504,
#      'nome': 'Bauru',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 350880115,
# ...
#    'microrregiao': {'id': 35046,
#     'nome': 'Sorocaba',
#     'mesorregiao': {'id': 3512,
#      'nome': 'Macro Metropolitana Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355230405,
#   'nome': 'Sud Mennucci',
#   'municipio': {'id': 3552304,
#    'nome': 'Sud Mennucci',
#    'microrregiao': {'id': 35016,
#     'nome': 'Andradina',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355230410,
#   'nome': "Bandeirantes D'Oeste",
#   'municipio': {'id': 3552304,
#    'nome': 'Sud Mennucci',
#    'microrregiao': {'id': 35016,
#     'nome': 'Andradina',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355240305,
#   'nome': 'Sumaré',
#   'municipio': {'id': 3552403,
#    'nome': 'Sumaré',
#    'microrregiao': {'id': 35032,
#     'nome': 'Campinas',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355240315,
#   'nome': 'Nova Veneza',
#   'municipio': {'id': 3552403,
#    'nome': 'Sumaré',
#    'microrregiao': {'id': 35032,
#     'nome': 'Campinas',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355255105,
#   'nome': 'Suzanápolis',
#   'municipio': {'id': 3552551,
#    'nome': 'Suzanápolis',
#    'microrregiao': {'id': 35016,
#     'nome': 'Andradina',
#     'mesorregiao': {'id': 3503,
#      'nome': 'Araçatuba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355250205,
#   'nome': 'Suzano',
#   'municipio': {'id': 3552502,
#    'nome': 'Suzano',
#    'microrregiao': {'id': 35062,
#     'nome': 'Mogi das Cruzes',
#     'mesorregiao': {'id': 3515,
#      'nome': 'Metropolitana de São Paulo',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355250210,
#   'nome': 'Boa Vista Paulista',
#   'municipio': {'id': 3552502,
#    'nome': 'Suzano',
#    'microrregiao': {'id': 35062,
#     'nome': 'Mogi das Cruzes',
#     'mesorregiao': {'id': 3515,
#      'nome': 'Metropolitana de São Paulo',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355250215,
#   'nome': 'Palmeiras de São Paulo',
#   'municipio': {'id': 3552502,
#    'nome': 'Suzano',
#    'microrregiao': {'id': 35062,
#     'nome': 'Mogi das Cruzes',
#     'mesorregiao': {'id': 3515,
#      'nome': 'Metropolitana de São Paulo',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355260105,
#   'nome': 'Tabapuã',
#   'municipio': {'id': 3552601,
#    'nome': 'Tabapuã',
#    'microrregiao': {'id': 35005,
#     'nome': 'Catanduva',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355270005,
#   'nome': 'Tabatinga',
#   'municipio': {'id': 3552700,
#    'nome': 'Tabatinga',
#    'microrregiao': {'id': 35024,
#     'nome': 'Araraquara',
#     'mesorregiao': {'id': 3505,
#      'nome': 'Araraquara',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355270010,
#   'nome': 'Curupá',
#   'municipio': {'id': 3552700,
#    'nome': 'Tabatinga',
#    'microrregiao': {'id': 35024,
#     'nome': 'Araraquara',
#     'mesorregiao': {'id': 3505,
#      'nome': 'Araraquara',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355280905,
#   'nome': 'Taboão da Serra',
#   'municipio': {'id': 3552809,
#    'nome': 'Taboão da Serra',
#    'microrregiao': {'id': 35060,
#     'nome': 'Itapecerica da Serra',
#     'mesorregiao': {'id': 3515,
#      'nome': 'Metropolitana de São Paulo',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355290805,
#   'nome': 'Taciba',
#   'municipio': {'id': 3552908,
#    'nome': 'Taciba',
#    'microrregiao': {'id': 35036,
#     'nome': 'Presidente Prudente',
#     'mesorregiao': {'id': 3508,
#      'nome': 'Presidente Prudente',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355300505,
#   'nome': 'Taguaí',
#   'municipio': {'id': 3553005,
#    'nome': 'Taguaí',
#    'microrregiao': {'id': 35040,
#     'nome': 'Ourinhos',
#     'mesorregiao': {'id': 3510,
#      'nome': 'Assis',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355310405,
#   'nome': 'Taiaçu',
#   'municipio': {'id': 3553104,
#    'nome': 'Taiaçu',
#    'microrregiao': {'id': 35013,
#     'nome': 'Jaboticabal',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355320305,
#   'nome': 'Taiúva',
#   'municipio': {'id': 3553203,
#    'nome': 'Taiúva',
#    'microrregiao': {'id': 35013,
#     'nome': 'Jaboticabal',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355330205,
#   'nome': 'Tambaú',
#   'municipio': {'id': 3553302,
#    'nome': 'Tambaú',
#    'microrregiao': {'id': 35030,
#     'nome': 'São João da Boa Vista',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355340105,
#   'nome': 'Tanabi',
#   'municipio': {'id': 3553401,
#    'nome': 'Tanabi',
#    'microrregiao': {'id': 35004,
#     'nome': 'São José do Rio Preto',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355340110,
#   'nome': 'Ibiporanga',
#   'municipio': {'id': 3553401,
#    'nome': 'Tanabi',
#    'microrregiao': {'id': 35004,
#     'nome': 'São José do Rio Preto',
#     'mesorregiao': {'id': 3501,
#      'nome': 'São José do Rio Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355350005,
#   'nome': 'Tapiraí',
#   'municipio': {'id': 3553500,
#    'nome': 'Tapiraí',
#    'microrregiao': {'id': 35045,
#     'nome': 'Piedade',
#     'mesorregiao': {'id': 3512,
#      'nome': 'Macro Metropolitana Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355350025,
#   'nome': 'Rio Turvo',
#   'municipio': {'id': 3553500,
#    'nome': 'Tapiraí',
#    'microrregiao': {'id': 35045,
#     'nome': 'Piedade',
#     'mesorregiao': {'id': 3512,
#      'nome': 'Macro Metropolitana Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355360905,
#   'nome': 'Tapiratiba',
#   'municipio': {'id': 3553609,
#    'nome': 'Tapiratiba',
#    'microrregiao': {'id': 35030,
#     'nome': 'São João da Boa Vista',
#     'mesorregiao': {'id': 3507,
#      'nome': 'Campinas',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355365805,
#   'nome': 'Taquaral',
#   'municipio': {'id': 3553658,
#    'nome': 'Taquaral',
#    'microrregiao': {'id': 35013,
#     'nome': 'Jaboticabal',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355370805,
#   'nome': 'Taquaritinga',
#   'municipio': {'id': 3553708,
#    'nome': 'Taquaritinga',
#    'microrregiao': {'id': 35013,
#     'nome': 'Jaboticabal',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355370810,
#   'nome': 'Guariroba',
#   'municipio': {'id': 3553708,
#    'nome': 'Taquaritinga',
#    'microrregiao': {'id': 35013,
#     'nome': 'Jaboticabal',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355370815,
#   'nome': 'Jurupema',
#   'municipio': {'id': 3553708,
#    'nome': 'Taquaritinga',
#    'microrregiao': {'id': 35013,
#     'nome': 'Jaboticabal',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355380705,
#   'nome': 'Taquarituba',
#   'municipio': {'id': 3553807,
#    'nome': 'Taquarituba',
#    'microrregiao': {'id': 35041,
#     'nome': 'Itapeva',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355385605,
#   'nome': 'Taquarivaí',
#   'municipio': {'id': 3553856,
#    'nome': 'Taquarivaí',
#    'microrregiao': {'id': 35041,
#     'nome': 'Itapeva',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355390605,
#   'nome': 'Tarabai',
#   'municipio': {'id': 3553906,
#    'nome': 'Tarabai',
#    'microrregiao': {'id': 35036,
#     'nome': 'Presidente Prudente',
#     'mesorregiao': {'id': 3508,
#      'nome': 'Presidente Prudente',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355395505,
#   'nome': 'Tarumã',
#   'municipio': {'id': 3553955,
#    'nome': 'Tarumã',
#    'microrregiao': {'id': 35039,
#     'nome': 'Assis',
#     'mesorregiao': {'id': 3510,
#      'nome': 'Assis',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355400305,
#   'nome': 'Tatuí',
#   'municipio': {'id': 3554003,
#    'nome': 'Tatuí',
#    'microrregiao': {'id': 35043,
#     'nome': 'Tatuí',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355410205,
#   'nome': 'Taubaté',
#   'municipio': {'id': 3554102,
#    'nome': 'Taubaté',
#    'microrregiao': {'id': 35050,
#     'nome': 'São José dos Campos',
#     'mesorregiao': {'id': 3513,
#      'nome': 'Vale do Paraíba Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355410210,
#   'nome': 'Quiririm',
#   'municipio': {'id': 3554102,
#    'nome': 'Taubaté',
#    'microrregiao': {'id': 35050,
#     'nome': 'São José dos Campos',
#     'mesorregiao': {'id': 3513,
#      'nome': 'Vale do Paraíba Paulista',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355420105,
#   'nome': 'Tejupá',
#   'municipio': {'id': 3554201,
#    'nome': 'Tejupá',
#    'microrregiao': {'id': 35040,
#     'nome': 'Ourinhos',
#     'mesorregiao': {'id': 3510,
#      'nome': 'Assis',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355420110,
#   'nome': 'Águas Virtuosas',
#   'municipio': {'id': 3554201,
#    'nome': 'Tejupá',
#    'microrregiao': {'id': 35040,
#     'nome': 'Ourinhos',
#     'mesorregiao': {'id': 3510,
#      'nome': 'Assis',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355420120,
#   'nome': 'Ribeirão Bonito',
#   'municipio': {'id': 3554201,
#    'nome': 'Tejupá',
#    'microrregiao': {'id': 35040,
#     'nome': 'Ourinhos',
#     'mesorregiao': {'id': 3510,
#      'nome': 'Assis',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355430005,
#   'nome': 'Teodoro Sampaio',
#   'municipio': {'id': 3554300,
#    'nome': 'Teodoro Sampaio',
#    'microrregiao': {'id': 35036,
#     'nome': 'Presidente Prudente',
#     'mesorregiao': {'id': 3508,
#      'nome': 'Presidente Prudente',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355430025,
#   'nome': 'Planalto do Sul',
#   'municipio': {'id': 3554300,
#    'nome': 'Teodoro Sampaio',
#    'microrregiao': {'id': 35036,
#     'nome': 'Presidente Prudente',
#     'mesorregiao': {'id': 3508,
#      'nome': 'Presidente Prudente',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355440905,
#   'nome': 'Terra Roxa',
#   'municipio': {'id': 3554409,
#    'nome': 'Terra Roxa',
#    'microrregiao': {'id': 35013,
#     'nome': 'Jaboticabal',
#     'mesorregiao': {'id': 3502,
#      'nome': 'Ribeirão Preto',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355450805,
#   'nome': 'Tietê',
#   'municipio': {'id': 3554508,
#    'nome': 'Tietê',
#    'microrregiao': {'id': 35028,
#     'nome': 'Piracicaba',
#     'mesorregiao': {'id': 3506,
#      'nome': 'Piracicaba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355460705,
#   'nome': 'Timburi',
#   'municipio': {'id': 3554607,
#    'nome': 'Timburi',
#    'microrregiao': {'id': 35040,
#     'nome': 'Ourinhos',
#     'mesorregiao': {'id': 3510,
#      'nome': 'Assis',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355465605,
#   'nome': 'Torre de Pedra',
#   'municipio': {'id': 3554656,
#    'nome': 'Torre de Pedra',
#    'microrregiao': {'id': 35043,
#     'nome': 'Tatuí',
#     'mesorregiao': {'id': 3511,
#      'nome': 'Itapetininga',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355470605,
#   'nome': 'Torrinha',
#   'municipio': {'id': 3554706,
#    'nome': 'Torrinha',
#    'microrregiao': {'id': 35026,
#     'nome': 'Rio Claro',
#     'mesorregiao': {'id': 3506,
#      'nome': 'Piracicaba',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  {'id': 355475505,
#   'nome': 'Trabiju',
#   'municipio': {'id': 3554755,
#    'nome': 'Trabiju',
#    'microrregiao': {'id': 35024,
#     'nome': 'Araraquara',
#     'mesorregiao': {'id': 3505,
#      'nome': 'Araraquara',
#      'UF': {'id': 35,
#       'sigla': 'SP',
#       'nome': 'São Paulo',
#       'regiao': {'id': 3, 'sigla': 'SE', 'nome': 'Sudeste'}}}}}},
#  ...]

# %%
def set_type_city(state,df_estados):
    capital = df_estados[df_estados['Sigla']=='SP']['Capital'].iloc[0]
    link = f'https://servicodados.ibge.gov.br/api/v1/localidades/estados/{state}/distritos'
    data_dict = requests.get(link).json()
    for data_cidade in data_dict:
        cidade = data_cidade['municipio']['nome']
        regiao = data_cidade['municipio']['microrregiao']['nome']
        tipo = 'Capital' if regiao == capital else 'Interior'
        print(f"Municipio: {cidade}\n\tregiao: {tipo}")
set_type_city('SP',estados)
# Out:
# Municipio: Adamantina
# 	regiao: Interior
# Municipio: Adolfo
# 	regiao: Interior
# Municipio: Aguaí
# 	regiao: Interior
# Municipio: Águas da Prata
# 	regiao: Interior
# Municipio: Águas da Prata
# 	regiao: Interior
# Municipio: Águas de Lindóia
# 	regiao: Interior
# Municipio: Águas de Santa Bárbara
# 	regiao: Interior
# Municipio: Águas de São Pedro
# 	regiao: Interior
# Municipio: Agudos
# 	regiao: Interior
# Municipio: Agudos
# 	regiao: Interior
# Municipio: Alambari
# 	regiao: Interior
# Municipio: Alfredo Marcondes
# 	regiao: Interior
# Municipio: Altair
# 	regiao: Interior
# Municipio: Altair
# 	regiao: Interior
# Municipio: Altinópolis
# 	regiao: Interior
# Municipio: Alto Alegre
# 	regiao: Interior
# Municipio: Alto Alegre
# 	regiao: Interior
# Municipio: Alto Alegre
# 	regiao: Interior
# Municipio: Alumínio
# 	regiao: Interior
# Municipio: Álvares Florence
# 	regiao: Interior
# Municipio: Álvares Florence
# 	regiao: Interior
# Municipio: Álvares Machado
# 	regiao: Interior
# Municipio: Álvares Machado
# 	regiao: Interior
# Municipio: Álvaro de Carvalho
# 	regiao: Interior
# Municipio: Alvinlândia
# 	regiao: Interior
# Municipio: Americana
# 	regiao: Interior
# Municipio: Américo Brasiliense
# 	regiao: Interior
# Municipio: Américo de Campos
# 	regiao: Interior
# Municipio: Amparo
# 	regiao: Interior
# Municipio: Amparo
# 	regiao: Interior
# Municipio: Amparo
# 	regiao: Interior
# Municipio: Analândia
# 	regiao: Interior
# Municipio: Andradina
# 	regiao: Interior
# Municipio: Angatuba
# 	regiao: Interior
# Municipio: Angatuba
# 	regiao: Interior
# Municipio: Anhembi
# 	regiao: Interior
# Municipio: Anhembi
# 	regiao: Interior
# Municipio: Anhumas
# 	regiao: Interior
# Municipio: Aparecida
# 	regiao: Interior
# Municipio: Aparecida d'Oeste
# 	regiao: Interior
# Municipio: Apiaí
# 	regiao: Interior
# Municipio: Apiaí
# 	regiao: Interior
# Municipio: Apiaí
# 	regiao: Interior
# Municipio: Apiaí
# 	regiao: Interior
# Municipio: Araçariguama
# 	regiao: Interior
# Municipio: Araçatuba
# 	regiao: Interior
# Municipio: Araçoiaba da Serra
# 	regiao: Interior
# Municipio: Aramina
# 	regiao: Interior
# Municipio: Arandu
# 	regiao: Interior
# Municipio: Arapeí
# 	regiao: Interior
# Municipio: Araraquara
# 	regiao: Interior
# Municipio: Araraquara
# 	regiao: Interior
# Municipio: Araraquara
# 	regiao: Interior
# Municipio: Araras
# 	regiao: Interior
# Municipio: Arco-Íris
# 	regiao: Interior
# Municipio: Arealva
# 	regiao: Interior
# Municipio: Arealva
# 	regiao: Interior
# Municipio: Areias
# 	regiao: Interior
# Municipio: Areiópolis
# 	regiao: Interior
# Municipio: Ariranha
# 	regiao: Interior
# Municipio: Artur Nogueira
# 	regiao: Interior
# Municipio: Arujá
# 	regiao: Interior
# Municipio: Aspásia
# 	regiao: Interior
# Municipio: Assis
# 	regiao: Interior
# Municipio: Atibaia
# 	regiao: Interior
# Municipio: Auriflama
# 	regiao: Interior
# Municipio: Avaí
# 	regiao: Interior
# Municipio: Avaí
# 	regiao: Interior
# Municipio: Avanhandava
# 	regiao: Interior
# Municipio: Avaré
# 	regiao: Interior
# Municipio: Bady Bassitt
# 	regiao: Interior
# Municipio: Balbinos
# 	regiao: Interior
# Municipio: Bálsamo
# 	regiao: Interior
# Municipio: Bananal
# 	regiao: Interior
# Municipio: Barão de Antonina
# 	regiao: Interior
# Municipio: Barbosa
# 	regiao: Interior
# Municipio: Bariri
# 	regiao: Interior
# Municipio: Barra Bonita
# 	regiao: Interior
# Municipio: Barra do Chapéu
# 	regiao: Interior
# Municipio: Barra do Turvo
# 	regiao: Interior
# Municipio: Barretos
# 	regiao: Interior
# Municipio: Barretos
# 	regiao: Interior
# Municipio: Barretos
# 	regiao: Interior
# Municipio: Barrinha
# 	regiao: Interior
# Municipio: Barueri
# 	regiao: Interior
# Municipio: Barueri
# 	regiao: Interior
# Municipio: Barueri
# 	regiao: Interior
# Municipio: Barueri
# 	regiao: Interior
# Municipio: Bastos
# 	regiao: Interior
# Municipio: Batatais
# 	regiao: Interior
# Municipio: Bauru
# 	regiao: Interior
# Municipio: Bauru
# 	regiao: Interior
# Municipio: Bebedouro
# 	regiao: Interior
# Municipio: Bebedouro
# 	regiao: Interior
# Municipio: Bebedouro
# 	regiao: Interior
# Municipio: Bento de Abreu
# 	regiao: Interior
# Municipio: Bernardino de Campos
# 	regiao: Interior
# Municipio: Bertioga
# 	regiao: Interior
# Municipio: Bilac
# 	regiao: Interior
# Municipio: Birigui
# 	regiao: Interior
# Municipio: Biritiba Mirim
# 	regiao: Interior
# Municipio: Boa Esperança do Sul
# 	regiao: Interior
# Municipio: Bocaina
# 	regiao: Interior
# Municipio: Bofete
# 	regiao: Interior
# Municipio: Bofete
# 	regiao: Interior
# Municipio: Boituva
# 	regiao: Interior
# Municipio: Bom Jesus dos Perdões
# 	regiao: Interior
# Municipio: Bom Sucesso de Itararé
# 	regiao: Interior
# Municipio: Borá
# 	regiao: Interior
# Municipio: Boracéia
# 	regiao: Interior
# Municipio: Borborema
# 	regiao: Interior
# Municipio: Borebi
# 	regiao: Interior
# Municipio: Botucatu
# 	regiao: Interior
# Municipio: Botucatu
# 	regiao: Interior
# Municipio: Botucatu
# 	regiao: Interior
# Municipio: Bragança Paulista
# 	regiao: Interior
# Municipio: Braúna
# 	regiao: Interior
# Municipio: Brejo Alegre
# 	regiao: Interior
# Municipio: Brodowski
# 	regiao: Interior
# Municipio: Brotas
# 	regiao: Interior
# Municipio: Brotas
# 	regiao: Interior
# Municipio: Buri
# 	regiao: Interior
# Municipio: Buri
# 	regiao: Interior
# Municipio: Buritama
# 	regiao: Interior
# Municipio: Buritizal
# 	regiao: Interior
# Municipio: Cabrália Paulista
# 	regiao: Interior
# Municipio: Cabreúva
# 	regiao: Interior
# Municipio: Cabreúva
# 	regiao: Interior
# Municipio: Cabreúva
# 	regiao: Interior
# Municipio: Caçapava
# 	regiao: Interior
# Municipio: Cachoeira Paulista
# 	regiao: Interior
# Municipio: Caconde
# 	regiao: Interior
# Municipio: Caconde
# 	regiao: Interior
# Municipio: Cafelândia
# 	regiao: Interior
# Municipio: Cafelândia
# 	regiao: Interior
# Municipio: Cafelândia
# 	regiao: Interior
# Municipio: Cafelândia
# 	regiao: Interior
# Municipio: Caiabu
# 	regiao: Interior
# Municipio: Caiabu
# 	regiao: Interior
# Municipio: Caiabu
# 	regiao: Interior
# Municipio: Caieiras
# 	regiao: Interior
# Municipio: Caiuá
# 	regiao: Interior
# Municipio: Cajamar
# 	regiao: Interior
# Municipio: Cajamar
# 	regiao: Interior
# Municipio: Cajamar
# 	regiao: Interior
# Municipio: Cajati
# 	regiao: Interior
# Municipio: Cajobi
# 	regiao: Interior
# Municipio: Cajobi
# 	regiao: Interior
# Municipio: Cajuru
# 	regiao: Interior
# Municipio: Campina do Monte Alegre
# 	regiao: Interior
# Municipio: Campina do Monte Alegre
# 	regiao: Interior
# Municipio: Campinas
# 	regiao: Interior
# Municipio: Campinas
# 	regiao: Interior
# Municipio: Campinas
# 	regiao: Interior
# Municipio: Campinas
# 	regiao: Interior
# Municipio: Campinas
# 	regiao: Interior
# Municipio: Campo Limpo Paulista
# 	regiao: Interior
# Municipio: Campo Limpo Paulista
# 	regiao: Interior
# Municipio: Campos do Jordão
# 	regiao: Interior
# Municipio: Campos Novos Paulista
# 	regiao: Interior
# Municipio: Cananéia
# 	regiao: Interior
# Municipio: Cananéia
# 	regiao: Interior
# Municipio: Canas
# 	regiao: Interior
# Municipio: Cândido Mota
# 	regiao: Interior
# Municipio: Cândido Mota
# 	regiao: Interior
# Municipio: Cândido Mota
# 	regiao: Interior
# Municipio: Cândido Mota
# 	regiao: Interior
# Municipio: Cândido Rodrigues
# 	regiao: Interior
# Municipio: Canitar
# 	regiao: Interior
# Municipio: Capão Bonito
# 	regiao: Interior
# Municipio: Capão Bonito
# 	regiao: Interior
# Municipio: Capela do Alto
# 	regiao: Interior
# Municipio: Capela do Alto
# 	regiao: Interior
# Municipio: Capivari
# 	regiao: Interior
# Municipio: Caraguatatuba
# 	regiao: Interior
# Municipio: Caraguatatuba
# 	regiao: Interior
# Municipio: Carapicuíba
# 	regiao: Interior
# Municipio: Carapicuíba
# 	regiao: Interior
# Municipio: Carapicuíba
# 	regiao: Interior
# Municipio: Cardoso
# 	regiao: Interior
# Municipio: Cardoso
# 	regiao: Interior
# Municipio: Casa Branca
# 	regiao: Interior
# Municipio: Casa Branca
# 	regiao: Interior
# Municipio: Casa Branca
# 	regiao: Interior
# Municipio: Cássia dos Coqueiros
# 	regiao: Interior
# Municipio: Castilho
# 	regiao: Interior
# Municipio: Catanduva
# 	regiao: Interior
# Municipio: Catiguá
# 	regiao: Interior
# Municipio: Cedral
# 	regiao: Interior
# Municipio: Cerqueira César
# 	regiao: Interior
# Municipio: Cerquilho
# 	regiao: Interior
# Municipio: Cesário Lange
# 	regiao: Interior
# Municipio: Cesário Lange
# 	regiao: Interior
# Municipio: Charqueada
# 	regiao: Interior
# Municipio: Charqueada
# 	regiao: Interior
# Municipio: Chavantes
# 	regiao: Interior
# Municipio: Chavantes
# 	regiao: Interior
# Municipio: Clementina
# 	regiao: Interior
# Municipio: Clementina
# 	regiao: Interior
# Municipio: Colina
# 	regiao: Interior
# Municipio: Colômbia
# 	regiao: Interior
# Municipio: Conchal
# 	regiao: Interior
# Municipio: Conchal
# 	regiao: Interior
# Municipio: Conchas
# 	regiao: Interior
# Municipio: Conchas
# 	regiao: Interior
# Municipio: Cordeirópolis
# 	regiao: Interior
# Municipio: Coroados
# 	regiao: Interior
# Municipio: Coronel Macedo
# 	regiao: Interior
# Municipio: Corumbataí
# 	regiao: Interior
# Municipio: Cosmópolis
# 	regiao: Interior
# Municipio: Cosmorama
# 	regiao: Interior
# Municipio: Cotia
# 	regiao: Interior
# Municipio: Cotia
# 	regiao: Interior
# Municipio: Cravinhos
# 	regiao: Interior
# Municipio: Cristais Paulista
# 	regiao: Interior
# Municipio: Cruzália
# 	regiao: Interior
# Municipio: Cruzeiro
# 	regiao: Interior
# Municipio: Cubatão
# 	regiao: Interior
# Municipio: Cunha
# 	regiao: Interior
# Municipio: Cunha
# 	regiao: Interior
# Municipio: Descalvado
# 	regiao: Interior
# Municipio: Diadema
# 	regiao: Capital
# Municipio: Dirce Reis
# 	regiao: Interior
# Municipio: Divinolândia
# 	regiao: Interior
# Municipio: Divinolândia
# 	regiao: Interior
# Municipio: Dobrada
# 	regiao: Interior
# Municipio: Dois Córregos
# 	regiao: Interior
# Municipio: Dois Córregos
# 	regiao: Interior
# Municipio: Dolcinópolis
# 	regiao: Interior
# Municipio: Dourado
# 	regiao: Interior
# Municipio: Dracena
# 	regiao: Interior
# Municipio: Dracena
# 	regiao: Interior
# Municipio: Dracena
# 	regiao: Interior
# Municipio: Duartina
# 	regiao: Interior
# Municipio: Dumont
# 	regiao: Interior
# Municipio: Echaporã
# 	regiao: Interior
# Municipio: Eldorado
# 	regiao: Interior
# Municipio: Eldorado
# 	regiao: Interior
# Municipio: Eldorado
# 	regiao: Interior
# Municipio: Elias Fausto
# 	regiao: Interior
# Municipio: Elias Fausto
# 	regiao: Interior
# Municipio: Elisiário
# 	regiao: Interior
# Municipio: Embaúba
# 	regiao: Interior
# Municipio: Embu das Artes
# 	regiao: Interior
# Municipio: Embu-Guaçu
# 	regiao: Interior
# Municipio: Embu-Guaçu
# 	regiao: Interior
# Municipio: Emilianópolis
# 	regiao: Interior
# Municipio: Engenheiro Coelho
# 	regiao: Interior
# Municipio: Espírito Santo do Pinhal
# 	regiao: Interior
# Municipio: Espírito Santo do Turvo
# 	regiao: Interior
# Municipio: Estiva Gerbi
# 	regiao: Interior
# Municipio: Estrela do Norte
# 	regiao: Interior
# Municipio: Estrela d'Oeste
# 	regiao: Interior
# Municipio: Euclides da Cunha Paulista
# 	regiao: Interior
# Municipio: Fartura
# 	regiao: Interior
# Municipio: Fernando Prestes
# 	regiao: Interior
# Municipio: Fernando Prestes
# 	regiao: Interior
# Municipio: Fernandópolis
# 	regiao: Interior
# Municipio: Fernandópolis
# 	regiao: Interior
# Municipio: Fernão
# 	regiao: Interior
# Municipio: Ferraz de Vasconcelos
# 	regiao: Interior
# Municipio: Ferraz de Vasconcelos
# 	regiao: Interior
# Municipio: Ferraz de Vasconcelos
# 	regiao: Interior
# Municipio: Flora Rica
# 	regiao: Interior
# Municipio: Floreal
# 	regiao: Interior
# Municipio: Flórida Paulista
# 	regiao: Interior
# Municipio: Flórida Paulista
# 	regiao: Interior
# Municipio: Flórida Paulista
# 	regiao: Interior
# Municipio: Florínea
# 	regiao: Interior
# Municipio: Franca
# 	regiao: Interior
# Municipio: Francisco Morato
# 	regiao: Interior
# Municipio: Franco da Rocha
# 	regiao: Interior
# Municipio: Gabriel Monteiro
# 	regiao: Interior
# Municipio: Gália
# 	regiao: Interior
# Municipio: Garça
# 	regiao: Interior
# Municipio: Garça
# 	regiao: Interior
# Municipio: Gastão Vidigal
# 	regiao: Interior
# Municipio: Gavião Peixoto
# 	regiao: Interior
# Municipio: General Salgado
# 	regiao: Interior
# Municipio: General Salgado
# 	regiao: Interior
# Municipio: Getulina
# 	regiao: Interior
# Municipio: Getulina
# 	regiao: Interior
# Municipio: Getulina
# 	regiao: Interior
# Municipio: Glicério
# 	regiao: Interior
# Municipio: Glicério
# 	regiao: Interior
# Municipio: Guaiçara
# 	regiao: Interior
# Municipio: Guaimbê
# 	regiao: Interior
# Municipio: Guaimbê
# 	regiao: Interior
# Municipio: Guaíra
# 	regiao: Interior
# Municipio: Guapiaçu
# 	regiao: Interior
# Municipio: Guapiara
# 	regiao: Interior
# Municipio: Guará
# 	regiao: Interior
# Municipio: Guará
# 	regiao: Interior
# Municipio: Guaraçaí
# 	regiao: Interior
# Municipio: Guaraci
# 	regiao: Interior
# Municipio: Guarani d'Oeste
# 	regiao: Interior
# Municipio: Guarantã
# 	regiao: Interior
# Municipio: Guararapes
# 	regiao: Interior
# Municipio: Guararapes
# 	regiao: Interior
# Municipio: Guararema
# 	regiao: Interior
# Municipio: Guaratinguetá
# 	regiao: Interior
# Municipio: Guareí
# 	regiao: Interior
# Municipio: Guariba
# 	regiao: Interior
# Municipio: Guarujá
# 	regiao: Interior
# Municipio: Guarujá
# 	regiao: Interior
# Municipio: Guarulhos
# 	regiao: Interior
# Municipio: Guarulhos
# 	regiao: Interior
# Municipio: Guatapará
# 	regiao: Interior
# Municipio: Guzolândia
# 	regiao: Interior
# Municipio: Herculândia
# 	regiao: Interior
# Municipio: Herculândia
# 	regiao: Interior
# Municipio: Holambra
# 	regiao: Interior
# Municipio: Hortolândia
# 	regiao: Interior
# Municipio: Iacanga
# 	regiao: Interior
# Municipio: Iacri
# 	regiao: Interior
# Municipio: Iacri
# 	regiao: Interior
# Municipio: Iaras
# 	regiao: Interior
# Municipio: Ibaté
# 	regiao: Interior
# Municipio: Ibirá
# 	regiao: Interior
# Municipio: Ibirá
# 	regiao: Interior
# Municipio: Ibirarema
# 	regiao: Interior
# Municipio: Ibitinga
# 	regiao: Interior
# Municipio: Ibitinga
# 	regiao: Interior
# Municipio: Ibiúna
# 	regiao: Interior
# Municipio: Ibiúna
# 	regiao: Interior
# Municipio: Icém
# 	regiao: Interior
# Municipio: Iepê
# 	regiao: Interior
# Municipio: Igaraçu do Tietê
# 	regiao: Interior
# Municipio: Igarapava
# 	regiao: Interior
# Municipio: Igaratá
# 	regiao: Interior
# Municipio: Iguape
# 	regiao: Interior
# Municipio: Ilha Comprida
# 	regiao: Interior
# Municipio: Ilha Solteira
# 	regiao: Interior
# Municipio: Ilhabela
# 	regiao: Interior
# Municipio: Ilhabela
# 	regiao: Interior
# Municipio: Ilhabela
# 	regiao: Interior
# Municipio: Indaiatuba
# 	regiao: Interior
# Municipio: Indiana
# 	regiao: Interior
# Municipio: Indiaporã
# 	regiao: Interior
# Municipio: Inúbia Paulista
# 	regiao: Interior
# Municipio: Ipaussu
# 	regiao: Interior
# Municipio: Iperó
# 	regiao: Interior
# Municipio: Iperó
# 	regiao: Interior
# Municipio: Ipeúna
# 	regiao: Interior
# Municipio: Ipiguá
# 	regiao: Interior
# Municipio: Iporanga
# 	regiao: Interior
# Municipio: Ipuã
# 	regiao: Interior
# Municipio: Iracemápolis
# 	regiao: Interior
# Municipio: Irapuã
# 	regiao: Interior
# Municipio: Irapuru
# 	regiao: Interior
# Municipio: Itaberá
# 	regiao: Interior
# Municipio: Itaberá
# 	regiao: Interior
# Municipio: Itaberá
# 	regiao: Interior
# Municipio: Itaberá
# 	regiao: Interior
# Municipio: Itaí
# 	regiao: Interior
# Municipio: Itajobi
# 	regiao: Interior
# Municipio: Itajobi
# 	regiao: Interior
# Municipio: Itaju
# 	regiao: Interior
# Municipio: Itanhaém
# 	regiao: Interior
# Municipio: Itaoca
# 	regiao: Interior
# Municipio: Itapecerica da Serra
# 	regiao: Interior
# Municipio: Itapetininga
# 	regiao: Interior
# Municipio: Itapetininga
# 	regiao: Interior
# Municipio: Itapetininga
# 	regiao: Interior
# Municipio: Itapetininga
# 	regiao: Interior
# Municipio: Itapetininga
# 	regiao: Interior
# Municipio: Itapetininga
# 	regiao: Interior
# Municipio: Itapetininga
# 	regiao: Interior
# Municipio: Itapeva
# 	regiao: Interior
# Municipio: Itapeva
# 	regiao: Interior
# Municipio: Itapeva
# 	regiao: Interior
# Municipio: Itapeva
# 	regiao: Interior
# Municipio: Itapevi
# 	regiao: Interior
# Municipio: Itapira
# 	regiao: Interior
# Municipio: Itapira
# 	regiao: Interior
# Municipio: Itapira
# 	regiao: Interior
# Municipio: Itapirapuã Paulista
# 	regiao: Interior
# Municipio: Itápolis
# 	regiao: Interior
# Municipio: Itápolis
# 	regiao: Interior
# Municipio: Itápolis
# 	regiao: Interior
# Municipio: Itaporanga
# 	regiao: Interior
# Municipio: Itapuí
# 	regiao: Interior
# Municipio: Itapura
# 	regiao: Interior
# Municipio: Itaquaquecetuba
# 	regiao: Interior
# Municipio: Itararé
# 	regiao: Interior
# Municipio: Itararé
# 	regiao: Interior
# Municipio: Itararé
# 	regiao: Interior
# Municipio: Itariri
# 	regiao: Interior
# Municipio: Itariri
# 	regiao: Interior
# Municipio: Itatiba
# 	regiao: Interior
# Municipio: Itatinga
# 	regiao: Interior
# Municipio: Itatinga
# 	regiao: Interior
# Municipio: Itirapina
# 	regiao: Interior
# Municipio: Itirapina
# 	regiao: Interior
# Municipio: Itirapuã
# 	regiao: Interior
# Municipio: Itobi
# 	regiao: Interior
# Municipio: Itu
# 	regiao: Interior
# Municipio: Itupeva
# 	regiao: Interior
# Municipio: Ituverava
# 	regiao: Interior
# Municipio: Ituverava
# 	regiao: Interior
# Municipio: Ituverava
# 	regiao: Interior
# Municipio: Jaborandi
# 	regiao: Interior
# Municipio: Jaboticabal
# 	regiao: Interior
# Municipio: Jaboticabal
# 	regiao: Interior
# Municipio: Jaboticabal
# 	regiao: Interior
# Municipio: Jacareí
# 	regiao: Interior
# Municipio: Jacareí
# 	regiao: Interior
# Municipio: Jacareí
# 	regiao: Interior
# Municipio: Jaci
# 	regiao: Interior
# Municipio: Jacupiranga
# 	regiao: Interior
# Municipio: Jaguariúna
# 	regiao: Interior
# Municipio: Jales
# 	regiao: Interior
# Municipio: Jambeiro
# 	regiao: Interior
# Municipio: Jandira
# 	regiao: Interior
# Municipio: Jardinópolis
# 	regiao: Interior
# Municipio: Jardinópolis
# 	regiao: Interior
# Municipio: Jarinu
# 	regiao: Interior
# Municipio: Jaú
# 	regiao: Interior
# Municipio: Jaú
# 	regiao: Interior
# Municipio: Jeriquara
# 	regiao: Interior
# Municipio: Joanópolis
# 	regiao: Interior
# Municipio: João Ramalho
# 	regiao: Interior
# Municipio: José Bonifácio
# 	regiao: Interior
# Municipio: Júlio Mesquita
# 	regiao: Interior
# Municipio: Jumirim
# 	regiao: Interior
# Municipio: Jundiaí
# 	regiao: Interior
# Municipio: Junqueirópolis
# 	regiao: Interior
# Municipio: Juquiá
# 	regiao: Interior
# Municipio: Juquitiba
# 	regiao: Interior
# Municipio: Juquitiba
# 	regiao: Interior
# Municipio: Lagoinha
# 	regiao: Interior
# Municipio: Laranjal Paulista
# 	regiao: Interior
# Municipio: Laranjal Paulista
# 	regiao: Interior
# Municipio: Laranjal Paulista
# 	regiao: Interior
# Municipio: Lavínia
# 	regiao: Interior
# Municipio: Lavínia
# 	regiao: Interior
# Municipio: Lavrinhas
# 	regiao: Interior
# Municipio: Lavrinhas
# 	regiao: Interior
# Municipio: Leme
# 	regiao: Interior
# Municipio: Lençóis Paulista
# 	regiao: Interior
# Municipio: Lençóis Paulista
# 	regiao: Interior
# Municipio: Limeira
# 	regiao: Interior
# Municipio: Lindóia
# 	regiao: Interior
# Municipio: Lins
# 	regiao: Interior
# Municipio: Lins
# 	regiao: Interior
# Municipio: Lorena
# 	regiao: Interior
# Municipio: Lourdes
# 	regiao: Interior
# Municipio: Louveira
# 	regiao: Interior
# Municipio: Lucélia
# 	regiao: Interior
# Municipio: Lucianópolis
# 	regiao: Interior
# Municipio: Luís Antônio
# 	regiao: Interior
# Municipio: Luiziânia
# 	regiao: Interior
# Municipio: Lupércio
# 	regiao: Interior
# Municipio: Lupércio
# 	regiao: Interior
# Municipio: Lutécia
# 	regiao: Interior
# Municipio: Macatuba
# 	regiao: Interior
# Municipio: Macaubal
# 	regiao: Interior
# Municipio: Macedônia
# 	regiao: Interior
# Municipio: Magda
# 	regiao: Interior
# Municipio: Mairinque
# 	regiao: Interior
# Municipio: Mairiporã
# 	regiao: Interior
# Municipio: Mairiporã
# 	regiao: Interior
# Municipio: Manduri
# 	regiao: Interior
# Municipio: Manduri
# 	regiao: Interior
# Municipio: Marabá Paulista
# 	regiao: Interior
# Municipio: Maracaí
# 	regiao: Interior
# Municipio: Maracaí
# 	regiao: Interior
# Municipio: Marapoama
# 	regiao: Interior
# Municipio: Mariápolis
# 	regiao: Interior
# Municipio: Mariápolis
# 	regiao: Interior
# Municipio: Marília
# 	regiao: Interior
# Municipio: Marília
# 	regiao: Interior
# Municipio: Marília
# 	regiao: Interior
# Municipio: Marília
# 	regiao: Interior
# Municipio: Marília
# 	regiao: Interior
# Municipio: Marília
# 	regiao: Interior
# Municipio: Marília
# 	regiao: Interior
# Municipio: Marinópolis
# 	regiao: Interior
# Municipio: Martinópolis
# 	regiao: Interior
# Municipio: Martinópolis
# 	regiao: Interior
# Municipio: Martinópolis
# 	regiao: Interior
# Municipio: Matão
# 	regiao: Interior
# Municipio: Matão
# 	regiao: Interior
# Municipio: Mauá
# 	regiao: Capital
# Municipio: Mendonça
# 	regiao: Interior
# Municipio: Meridiano
# 	regiao: Interior
# Municipio: Mesópolis
# 	regiao: Interior
# Municipio: Miguelópolis
# 	regiao: Interior
# Municipio: Mineiros do Tietê
# 	regiao: Interior
# Municipio: Mira Estrela
# 	regiao: Interior
# Municipio: Miracatu
# 	regiao: Interior
# Municipio: Miracatu
# 	regiao: Interior
# Municipio: Miracatu
# 	regiao: Interior
# Municipio: Miracatu
# 	regiao: Interior
# Municipio: Mirandópolis
# 	regiao: Interior
# Municipio: Mirandópolis
# 	regiao: Interior
# Municipio: Mirandópolis
# 	regiao: Interior
# Municipio: Mirante do Paranapanema
# 	regiao: Interior
# Municipio: Mirante do Paranapanema
# 	regiao: Interior
# Municipio: Mirante do Paranapanema
# 	regiao: Interior
# Municipio: Mirassol
# 	regiao: Interior
# Municipio: Mirassol
# 	regiao: Interior
# Municipio: Mirassolândia
# 	regiao: Interior
# Municipio: Mococa
# 	regiao: Interior
# Municipio: Mococa
# 	regiao: Interior
# Municipio: Mococa
# 	regiao: Interior
# Municipio: Mogi das Cruzes
# 	regiao: Interior
# Municipio: Mogi das Cruzes
# 	regiao: Interior
# Municipio: Mogi das Cruzes
# 	regiao: Interior
# Municipio: Mogi das Cruzes
# 	regiao: Interior
# Municipio: Mogi das Cruzes
# 	regiao: Interior
# Municipio: Mogi das Cruzes
# 	regiao: Interior
# Municipio: Mogi das Cruzes
# 	regiao: Interior
# Municipio: Mogi das Cruzes
# 	regiao: Interior
# Municipio: Mogi Guaçu
# 	regiao: Interior
# Municipio: Mogi Guaçu
# 	regiao: Interior
# Municipio: Mogi Mirim
# 	regiao: Interior
# Municipio: Mogi Mirim
# 	regiao: Interior
# Municipio: Mombuca
# 	regiao: Interior
# Municipio: Monções
# 	regiao: Interior
# Municipio: Mongaguá
# 	regiao: Interior
# Municipio: Monte Alegre do Sul
# 	regiao: Interior
# Municipio: Monte Alegre do Sul
# 	regiao: Interior
# Municipio: Monte Alto
# 	regiao: Interior
# Municipio: Monte Alto
# 	regiao: Interior
# Municipio: Monte Aprazível
# 	regiao: Interior
# Municipio: Monte Aprazível
# 	regiao: Interior
# Municipio: Monte Aprazível
# 	regiao: Interior
# Municipio: Monte Aprazível
# 	regiao: Interior
# Municipio: Monte Azul Paulista
# 	regiao: Interior
# Municipio: Monte Azul Paulista
# 	regiao: Interior
# Municipio: Monte Castelo
# 	regiao: Interior
# Municipio: Monte Mor
# 	regiao: Interior
# Municipio: Monteiro Lobato
# 	regiao: Interior
# Municipio: Morro Agudo
# 	regiao: Interior
# Municipio: Morungaba
# 	regiao: Interior
# Municipio: Motuca
# 	regiao: Interior
# Municipio: Murutinga do Sul
# 	regiao: Interior
# Municipio: Nantes
# 	regiao: Interior
# Municipio: Narandiba
# 	regiao: Interior
# Municipio: Natividade da Serra
# 	regiao: Interior
# Municipio: Natividade da Serra
# 	regiao: Interior
# Municipio: Nazaré Paulista
# 	regiao: Interior
# Municipio: Neves Paulista
# 	regiao: Interior
# Municipio: Neves Paulista
# 	regiao: Interior
# Municipio: Neves Paulista
# 	regiao: Interior
# Municipio: Nhandeara
# 	regiao: Interior
# Municipio: Nhandeara
# 	regiao: Interior
# Municipio: Nipoã
# 	regiao: Interior
# Municipio: Nova Aliança
# 	regiao: Interior
# Municipio: Nova Aliança
# 	regiao: Interior
# Municipio: Nova Campina
# 	regiao: Interior
# Municipio: Nova Campina
# 	regiao: Interior
# Municipio: Nova Canaã Paulista
# 	regiao: Interior
# Municipio: Nova Castilho
# 	regiao: Interior
# Municipio: Nova Europa
# 	regiao: Interior
# Municipio: Nova Granada
# 	regiao: Interior
# Municipio: Nova Granada
# 	regiao: Interior
# Municipio: Nova Granada
# 	regiao: Interior
# Municipio: Nova Granada
# 	regiao: Interior
# Municipio: Nova Guataporanga
# 	regiao: Interior
# Municipio: Nova Independência
# 	regiao: Interior
# Municipio: Nova Luzitânia
# 	regiao: Interior
# Municipio: Nova Odessa
# 	regiao: Interior
# Municipio: Novais
# 	regiao: Interior
# Municipio: Novo Horizonte
# 	regiao: Interior
# Municipio: Novo Horizonte
# 	regiao: Interior
# Municipio: Nuporanga
# 	regiao: Interior
# Municipio: Ocauçu
# 	regiao: Interior
# Municipio: Óleo
# 	regiao: Interior
# Municipio: Óleo
# 	regiao: Interior
# Municipio: Olímpia
# 	regiao: Interior
# Municipio: Olímpia
# 	regiao: Interior
# Municipio: Olímpia
# 	regiao: Interior
# Municipio: Onda Verde
# 	regiao: Interior
# Municipio: Oriente
# 	regiao: Interior
# Municipio: Orindiúva
# 	regiao: Interior
# Municipio: Orlândia
# 	regiao: Interior
# Municipio: Osasco
# 	regiao: Interior
# Municipio: Oscar Bressane
# 	regiao: Interior
# Municipio: Osvaldo Cruz
# 	regiao: Interior
# Municipio: Osvaldo Cruz
# 	regiao: Interior
# Municipio: Ourinhos
# 	regiao: Interior
# Municipio: Ouro Verde
# 	regiao: Interior
# Municipio: Ouroeste
# 	regiao: Interior
# Municipio: Pacaembu
# 	regiao: Interior
# Municipio: Palestina
# 	regiao: Interior
# Municipio: Palestina
# 	regiao: Interior
# Municipio: Palestina
# 	regiao: Interior
# Municipio: Palmares Paulista
# 	regiao: Interior
# Municipio: Palmeira d'Oeste
# 	regiao: Interior
# Municipio: Palmeira d'Oeste
# 	regiao: Interior
# Municipio: Palmital
# 	regiao: Interior
# Municipio: Palmital
# 	regiao: Interior
# Municipio: Panorama
# 	regiao: Interior
# Municipio: Paraguaçu Paulista
# 	regiao: Interior
# Municipio: Paraguaçu Paulista
# 	regiao: Interior
# Municipio: Paraguaçu Paulista
# 	regiao: Interior
# Municipio: Paraguaçu Paulista
# 	regiao: Interior
# Municipio: Paraibuna
# 	regiao: Interior
# Municipio: Paraíso
# 	regiao: Interior
# Municipio: Paranapanema
# 	regiao: Interior
# Municipio: Paranapuã
# 	regiao: Interior
# Municipio: Parapuã
# 	regiao: Interior
# Municipio: Pardinho
# 	regiao: Interior
# Municipio: Pariquera-Açu
# 	regiao: Interior
# Municipio: Parisi
# 	regiao: Interior
# Municipio: Patrocínio Paulista
# 	regiao: Interior
# Municipio: Paulicéia
# 	regiao: Interior
# Municipio: Paulínia
# 	regiao: Interior
# Municipio: Paulistânia
# 	regiao: Interior
# Municipio: Paulo de Faria
# 	regiao: Interior
# Municipio: Pederneiras
# 	regiao: Interior
# Municipio: Pederneiras
# 	regiao: Interior
# Municipio: Pederneiras
# 	regiao: Interior
# Municipio: Pederneiras
# 	regiao: Interior
# Municipio: Pedra Bela
# 	regiao: Interior
# Municipio: Pedranópolis
# 	regiao: Interior
# Municipio: Pedranópolis
# 	regiao: Interior
# Municipio: Pedregulho
# 	regiao: Interior
# Municipio: Pedregulho
# 	regiao: Interior
# Municipio: Pedregulho
# 	regiao: Interior
# Municipio: Pedreira
# 	regiao: Interior
# Municipio: Pedrinhas Paulista
# 	regiao: Interior
# Municipio: Pedro de Toledo
# 	regiao: Interior
# Municipio: Penápolis
# 	regiao: Interior
# Municipio: Pereira Barreto
# 	regiao: Interior
# Municipio: Pereiras
# 	regiao: Interior
# Municipio: Peruíbe
# 	regiao: Interior
# Municipio: Piacatu
# 	regiao: Interior
# Municipio: Piedade
# 	regiao: Interior
# Municipio: Pilar do Sul
# 	regiao: Interior
# Municipio: Pindamonhangaba
# 	regiao: Interior
# Municipio: Pindamonhangaba
# 	regiao: Interior
# Municipio: Pindorama
# 	regiao: Interior
# Municipio: Pindorama
# 	regiao: Interior
# Municipio: Pinhalzinho
# 	regiao: Interior
# Municipio: Piquerobi
# 	regiao: Interior
# Municipio: Piquete
# 	regiao: Interior
# Municipio: Piracaia
# 	regiao: Interior
# Municipio: Piracaia
# 	regiao: Interior
# Municipio: Piracicaba
# 	regiao: Interior
# Municipio: Piracicaba
# 	regiao: Interior
# Municipio: Piracicaba
# 	regiao: Interior
# Municipio: Piracicaba
# 	regiao: Interior
# Municipio: Piracicaba
# 	regiao: Interior
# Municipio: Piracicaba
# 	regiao: Interior
# Municipio: Piraju
# 	regiao: Interior
# Municipio: Piraju
# 	regiao: Interior
# Municipio: Pirajuí
# 	regiao: Interior
# Municipio: Pirajuí
# 	regiao: Interior
# Municipio: Pirajuí
# 	regiao: Interior
# Municipio: Pirajuí
# 	regiao: Interior
# Municipio: Pirangi
# 	regiao: Interior
# Municipio: Pirapora do Bom Jesus
# 	regiao: Interior
# Municipio: Pirapozinho
# 	regiao: Interior
# Municipio: Pirapozinho
# 	regiao: Interior
# Municipio: Pirassununga
# 	regiao: Interior
# Municipio: Pirassununga
# 	regiao: Interior
# Municipio: Piratininga
# 	regiao: Interior
# Municipio: Pitangueiras
# 	regiao: Interior
# Municipio: Pitangueiras
# 	regiao: Interior
# Municipio: Planalto
# 	regiao: Interior
# Municipio: Platina
# 	regiao: Interior
# Municipio: Poá
# 	regiao: Interior
# Municipio: Poá
# 	regiao: Interior
# Municipio: Poloni
# 	regiao: Interior
# Municipio: Pompéia
# 	regiao: Interior
# Municipio: Pompéia
# 	regiao: Interior
# Municipio: Pompéia
# 	regiao: Interior
# Municipio: Pongaí
# 	regiao: Interior
# Municipio: Pontal
# 	regiao: Interior
# Municipio: Pontal
# 	regiao: Interior
# Municipio: Pontalinda
# 	regiao: Interior
# Municipio: Pontes Gestal
# 	regiao: Interior
# Municipio: Populina
# 	regiao: Interior
# Municipio: Porangaba
# 	regiao: Interior
# Municipio: Porto Feliz
# 	regiao: Interior
# Municipio: Porto Ferreira
# 	regiao: Interior
# Municipio: Potim
# 	regiao: Interior
# Municipio: Potirendaba
# 	regiao: Interior
# Municipio: Pracinha
# 	regiao: Interior
# Municipio: Pradópolis
# 	regiao: Interior
# Municipio: Praia Grande
# 	regiao: Interior
# Municipio: Praia Grande
# 	regiao: Interior
# Municipio: Pratânia
# 	regiao: Interior
# Municipio: Presidente Alves
# 	regiao: Interior
# Municipio: Presidente Alves
# 	regiao: Interior
# Municipio: Presidente Bernardes
# 	regiao: Interior
# Municipio: Presidente Bernardes
# 	regiao: Interior
# Municipio: Presidente Bernardes
# 	regiao: Interior
# Municipio: Presidente Epitácio
# 	regiao: Interior
# Municipio: Presidente Epitácio
# 	regiao: Interior
# Municipio: Presidente Prudente
# 	regiao: Interior
# Municipio: Presidente Prudente
# 	regiao: Interior
# Municipio: Presidente Prudente
# 	regiao: Interior
# Municipio: Presidente Prudente
# 	regiao: Interior
# Municipio: Presidente Prudente
# 	regiao: Interior
# Municipio: Presidente Venceslau
# 	regiao: Interior
# Municipio: Promissão
# 	regiao: Interior
# Municipio: Promissão
# 	regiao: Interior
# Municipio: Quadra
# 	regiao: Interior
# Municipio: Quatá
# 	regiao: Interior
# Municipio: Queiroz
# 	regiao: Interior
# Municipio: Queluz
# 	regiao: Interior
# Municipio: Quintana
# 	regiao: Interior
# Municipio: Rafard
# 	regiao: Interior
# Municipio: Rancharia
# 	regiao: Interior
# Municipio: Rancharia
# 	regiao: Interior
# Municipio: Rancharia
# 	regiao: Interior
# Municipio: Redenção da Serra
# 	regiao: Interior
# Municipio: Regente Feijó
# 	regiao: Interior
# Municipio: Regente Feijó
# 	regiao: Interior
# Municipio: Reginópolis
# 	regiao: Interior
# Municipio: Registro
# 	regiao: Interior
# Municipio: Restinga
# 	regiao: Interior
# Municipio: Ribeira
# 	regiao: Interior
# Municipio: Ribeirão Bonito
# 	regiao: Interior
# Municipio: Ribeirão Bonito
# 	regiao: Interior
# Municipio: Ribeirão Branco
# 	regiao: Interior
# Municipio: Ribeirão Branco
# 	regiao: Interior
# Municipio: Ribeirão Branco
# 	regiao: Interior
# Municipio: Ribeirão Corrente
# 	regiao: Interior
# Municipio: Ribeirão do Sul
# 	regiao: Interior
# Municipio: Ribeirão dos Índios
# 	regiao: Interior
# Municipio: Ribeirão Grande
# 	regiao: Interior
# Municipio: Ribeirão Pires
# 	regiao: Capital
# Municipio: Ribeirão Pires
# 	regiao: Capital
# Municipio: Ribeirão Pires
# 	regiao: Capital
# Municipio: Ribeirão Preto
# 	regiao: Interior
# Municipio: Ribeirão Preto
# 	regiao: Interior
# Municipio: Rifaina
# 	regiao: Interior
# Municipio: Rincão
# 	regiao: Interior
# Municipio: Rinópolis
# 	regiao: Interior
# Municipio: Rio Claro
# 	regiao: Interior
# Municipio: Rio Claro
# 	regiao: Interior
# Municipio: Rio Claro
# 	regiao: Interior
# Municipio: Rio das Pedras
# 	regiao: Interior
# Municipio: Rio Grande da Serra
# 	regiao: Capital
# Municipio: Riolândia
# 	regiao: Interior
# Municipio: Riversul
# 	regiao: Interior
# Municipio: Rosana
# 	regiao: Interior
# Municipio: Roseira
# 	regiao: Interior
# Municipio: Rubiácea
# 	regiao: Interior
# Municipio: Rubinéia
# 	regiao: Interior
# Municipio: Rubinéia
# 	regiao: Interior
# Municipio: Sabino
# 	regiao: Interior
# Municipio: Sagres
# 	regiao: Interior
# Municipio: Sales
# 	regiao: Interior
# Municipio: Sales Oliveira
# 	regiao: Interior
# Municipio: Salesópolis
# 	regiao: Interior
# Municipio: Salesópolis
# 	regiao: Interior
# Municipio: Salmourão
# 	regiao: Interior
# Municipio: Saltinho
# 	regiao: Interior
# Municipio: Salto
# 	regiao: Interior
# Municipio: Salto de Pirapora
# 	regiao: Interior
# Municipio: Salto Grande
# 	regiao: Interior
# Municipio: Sandovalina
# 	regiao: Interior
# Municipio: Santa Adélia
# 	regiao: Interior
# Municipio: Santa Adélia
# 	regiao: Interior
# Municipio: Santa Adélia
# 	regiao: Interior
# Municipio: Santa Adélia
# 	regiao: Interior
# Municipio: Santa Albertina
# 	regiao: Interior
# Municipio: Santa Bárbara d'Oeste
# 	regiao: Interior
# Municipio: Santa Branca
# 	regiao: Interior
# Municipio: Santa Clara d'Oeste
# 	regiao: Interior
# Municipio: Santa Cruz da Conceição
# 	regiao: Interior
# Municipio: Santa Cruz da Esperança
# 	regiao: Interior
# Municipio: Santa Cruz das Palmeiras
# 	regiao: Interior
# Municipio: Santa Cruz do Rio Pardo
# 	regiao: Interior
# Municipio: Santa Cruz do Rio Pardo
# 	regiao: Interior
# Municipio: Santa Cruz do Rio Pardo
# 	regiao: Interior
# Municipio: Santa Cruz do Rio Pardo
# 	regiao: Interior
# Municipio: Santa Ernestina
# 	regiao: Interior
# Municipio: Santa Fé do Sul
# 	regiao: Interior
# Municipio: Santa Gertrudes
# 	regiao: Interior
# Municipio: Santa Isabel
# 	regiao: Interior
# Municipio: Santa Lúcia
# 	regiao: Interior
# Municipio: Santa Maria da Serra
# 	regiao: Interior
# Municipio: Santa Mercedes
# 	regiao: Interior
# Municipio: Santa Mercedes
# 	regiao: Interior
# Municipio: Santa Rita do Passa Quatro
# 	regiao: Interior
# Municipio: Santa Rita do Passa Quatro
# 	regiao: Interior
# Municipio: Santa Rita d'Oeste
# 	regiao: Interior
# Municipio: Santa Rita d'Oeste
# 	regiao: Interior
# Municipio: Santa Rosa de Viterbo
# 	regiao: Interior
# Municipio: Santa Salete
# 	regiao: Interior
# Municipio: Santana da Ponte Pensa
# 	regiao: Interior
# Municipio: Santana de Parnaíba
# 	regiao: Interior
# Municipio: Santo Anastácio
# 	regiao: Interior
# Municipio: Santo André
# 	regiao: Capital
# Municipio: Santo André
# 	regiao: Capital
# Municipio: Santo André
# 	regiao: Capital
# Municipio: Santo Antônio da Alegria
# 	regiao: Interior
# Municipio: Santo Antônio de Posse
# 	regiao: Interior
# Municipio: Santo Antônio do Aracanguá
# 	regiao: Interior
# Municipio: Santo Antônio do Aracanguá
# 	regiao: Interior
# Municipio: Santo Antônio do Aracanguá
# 	regiao: Interior
# Municipio: Santo Antônio do Jardim
# 	regiao: Interior
# Municipio: Santo Antônio do Pinhal
# 	regiao: Interior
# Municipio: Santo Expedito
# 	regiao: Interior
# Municipio: Santópolis do Aguapeí
# 	regiao: Interior
# Municipio: Santos
# 	regiao: Interior
# Municipio: São Bento do Sapucaí
# 	regiao: Interior
# Municipio: São Bernardo do Campo
# 	regiao: Capital
# Municipio: São Bernardo do Campo
# 	regiao: Capital
# Municipio: São Caetano do Sul
# 	regiao: Capital
# Municipio: São Carlos
# 	regiao: Interior
# Municipio: São Carlos
# 	regiao: Interior
# Municipio: São Carlos
# 	regiao: Interior
# Municipio: São Carlos
# 	regiao: Interior
# Municipio: São Carlos
# 	regiao: Interior
# Municipio: São Francisco
# 	regiao: Interior
# Municipio: São João da Boa Vista
# 	regiao: Interior
# Municipio: São João das Duas Pontes
# 	regiao: Interior
# Municipio: São João de Iracema
# 	regiao: Interior
# Municipio: São João do Pau d'Alho
# 	regiao: Interior
# Municipio: São Joaquim da Barra
# 	regiao: Interior
# Municipio: São José da Bela Vista
# 	regiao: Interior
# Municipio: São José do Barreiro
# 	regiao: Interior
# Municipio: São José do Rio Pardo
# 	regiao: Interior
# Municipio: São José do Rio Preto
# 	regiao: Interior
# Municipio: São José do Rio Preto
# 	regiao: Interior
# Municipio: São José do Rio Preto
# 	regiao: Interior
# Municipio: São José dos Campos
# 	regiao: Interior
# Municipio: São José dos Campos
# 	regiao: Interior
# Municipio: São José dos Campos
# 	regiao: Interior
# Municipio: São Lourenço da Serra
# 	regiao: Interior
# Municipio: São Luiz do Paraitinga
# 	regiao: Interior
# Municipio: São Luiz do Paraitinga
# 	regiao: Interior
# Municipio: São Manuel
# 	regiao: Interior
# Municipio: São Manuel
# 	regiao: Interior
# Municipio: São Miguel Arcanjo
# 	regiao: Interior
# Municipio: São Miguel Arcanjo
# 	regiao: Interior
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Paulo
# 	regiao: Capital
# Municipio: São Pedro
# 	regiao: Interior
# Municipio: São Pedro do Turvo
# 	regiao: Interior
# Municipio: São Roque
# 	regiao: Interior
# Municipio: São Roque
# 	regiao: Interior
# Municipio: São Roque
# 	regiao: Interior
# Municipio: São Roque
# 	regiao: Interior
# Municipio: São Sebastião
# 	regiao: Interior
# Municipio: São Sebastião
# 	regiao: Interior
# Municipio: São Sebastião
# 	regiao: Interior
# Municipio: São Sebastião da Grama
# 	regiao: Interior
# Municipio: São Simão
# 	regiao: Interior
# Municipio: São Vicente
# 	regiao: Interior
# Municipio: Sarapuí
# 	regiao: Interior
# Municipio: Sarapuí
# 	regiao: Interior
# Municipio: Sarutaiá
# 	regiao: Interior
# Municipio: Sebastianópolis do Sul
# 	regiao: Interior
# Municipio: Serra Azul
# 	regiao: Interior
# Municipio: Serra Negra
# 	regiao: Interior
# Municipio: Serrana
# 	regiao: Interior
# Municipio: Sertãozinho
# 	regiao: Interior
# Municipio: Sertãozinho
# 	regiao: Interior
# Municipio: Sete Barras
# 	regiao: Interior
# Municipio: Severínia
# 	regiao: Interior
# Municipio: Silveiras
# 	regiao: Interior
# Municipio: Socorro
# 	regiao: Interior
# Municipio: Sorocaba
# 	regiao: Interior
# Municipio: Sud Mennucci
# 	regiao: Interior
# Municipio: Sud Mennucci
# 	regiao: Interior
# Municipio: Sumaré
# 	regiao: Interior
# Municipio: Sumaré
# 	regiao: Interior
# Municipio: Suzanápolis
# 	regiao: Interior
# Municipio: Suzano
# 	regiao: Interior
# Municipio: Suzano
# 	regiao: Interior
# Municipio: Suzano
# 	regiao: Interior
# Municipio: Tabapuã
# 	regiao: Interior
# Municipio: Tabatinga
# 	regiao: Interior
# Municipio: Tabatinga
# 	regiao: Interior
# Municipio: Taboão da Serra
# 	regiao: Interior
# Municipio: Taciba
# 	regiao: Interior
# Municipio: Taguaí
# 	regiao: Interior
# Municipio: Taiaçu
# 	regiao: Interior
# Municipio: Taiúva
# 	regiao: Interior
# Municipio: Tambaú
# 	regiao: Interior
# Municipio: Tanabi
# 	regiao: Interior
# Municipio: Tanabi
# 	regiao: Interior
# Municipio: Tapiraí
# 	regiao: Interior
# Municipio: Tapiraí
# 	regiao: Interior
# Municipio: Tapiratiba
# 	regiao: Interior
# Municipio: Taquaral
# 	regiao: Interior
# Municipio: Taquaritinga
# 	regiao: Interior
# Municipio: Taquaritinga
# 	regiao: Interior
# Municipio: Taquaritinga
# 	regiao: Interior
# Municipio: Taquarituba
# 	regiao: Interior
# Municipio: Taquarivaí
# 	regiao: Interior
# Municipio: Tarabai
# 	regiao: Interior
# Municipio: Tarumã
# 	regiao: Interior
# Municipio: Tatuí
# 	regiao: Interior
# Municipio: Taubaté
# 	regiao: Interior
# Municipio: Taubaté
# 	regiao: Interior
# Municipio: Tejupá
# 	regiao: Interior
# Municipio: Tejupá
# 	regiao: Interior
# Municipio: Tejupá
# 	regiao: Interior
# Municipio: Teodoro Sampaio
# 	regiao: Interior
# Municipio: Teodoro Sampaio
# 	regiao: Interior
# Municipio: Terra Roxa
# 	regiao: Interior
# Municipio: Tietê
# 	regiao: Interior
# Municipio: Timburi
# 	regiao: Interior
# Municipio: Torre de Pedra
# 	regiao: Interior
# Municipio: Torrinha
# 	regiao: Interior
# Municipio: Trabiju
# 	regiao: Interior
# Municipio: Tremembé
# 	regiao: Interior
# Municipio: Três Fronteiras
# 	regiao: Interior
# Municipio: Tuiuti
# 	regiao: Interior
# Municipio: Tupã
# 	regiao: Interior
# Municipio: Tupã
# 	regiao: Interior
# Municipio: Tupã
# 	regiao: Interior
# Municipio: Tupã
# 	regiao: Interior
# Municipio: Tupi Paulista
# 	regiao: Interior
# Municipio: Tupi Paulista
# 	regiao: Interior
# Municipio: Turiúba
# 	regiao: Interior
# Municipio: Turmalina
# 	regiao: Interior
# Municipio: Turmalina
# 	regiao: Interior
# Municipio: Ubarana
# 	regiao: Interior
# Municipio: Ubatuba
# 	regiao: Interior
# Municipio: Ubatuba
# 	regiao: Interior
# Municipio: Ubirajara
# 	regiao: Interior
# Municipio: Ubirajara
# 	regiao: Interior
# Municipio: Uchoa
# 	regiao: Interior
# Municipio: União Paulista
# 	regiao: Interior
# Municipio: Urânia
# 	regiao: Interior
# Municipio: Uru
# 	regiao: Interior
# Municipio: Urupês
# 	regiao: Interior
# Municipio: Urupês
# 	regiao: Interior
# Municipio: Valentim Gentil
# 	regiao: Interior
# Municipio: Valinhos
# 	regiao: Interior
# Municipio: Valparaíso
# 	regiao: Interior
# Municipio: Vargem
# 	regiao: Interior
# Municipio: Vargem Grande do Sul
# 	regiao: Interior
# Municipio: Vargem Grande Paulista
# 	regiao: Interior
# Municipio: Várzea Paulista
# 	regiao: Interior
# Municipio: Vera Cruz
# 	regiao: Interior
# Municipio: Vinhedo
# 	regiao: Interior
# Municipio: Viradouro
# 	regiao: Interior
# Municipio: Vista Alegre do Alto
# 	regiao: Interior
# Municipio: Vitória Brasil
# 	regiao: Interior
# Municipio: Votorantim
# 	regiao: Interior
# Municipio: Votuporanga
# 	regiao: Interior
# Municipio: Votuporanga
# 	regiao: Interior
# Municipio: Zacarias
# 	regiao: Interior

# %%
link = f'https://servicodados.ibge.gov.br/api/v1/localidades/estados/PE/distritos'
data_dict = requests.get(link).json()
for data_cidade in data_dict:
    cidade = data_cidade['municipio']['nome']
    if cidade == 'Recife':
        regiao = data_cidade['municipio']['microrregiao']['mesorregiao']['nome']
        print(regiao)
# Out:
# Metropolitana de Recife

# %% [markdown]
# # Extras

# %% [markdown]
# ## Pegando estados

# %%
import pandas as pd

# %%
dfs = pd.read_html('https://www.estadosecapitaisdobrasil.com/')
estados = dfs[0]
estados.drop('Bandeira',axis=1,inplace=True)

# %%
estados.to_csv('estados.csv')

# %%
estados
# Out:
#                  Estado Sigla         Capital        Região
# 0                  Acre    AC      Rio Branco         Norte
# 1               Alagoas    AL          Maceió      Nordeste
# 2                 Amapá    AP          Macapá         Norte
# 3              Amazonas    AM          Manaus         Norte
# 4                 Bahia    BA        Salvador      Nordeste
# 5                 Ceará    CE       Fortaleza      Nordeste
# 6      Distrito Federal    DF        Brasília  Centro-Oeste
# 7        Espírito Santo    ES         Vitória       Sudeste
# 8                 Goiás    GO         Goiânia  Centro-Oeste
# 9              Maranhão    MA        São Luís      Nordeste
# 10          Mato Grosso    MT          Cuiabá  Centro-Oeste
# 11   Mato Grosso do Sul    MS    Campo Grande  Centro-Oeste
# 12         Minas Gerais    MG  Belo Horizonte       Sudeste
# 13                 Pará    PA           Belém         Norte
# 14              Paraíba    PB     João Pessoa      Nordeste
# 15               Paraná    PR        Curitiba           Sul
# 16           Pernambuco    PE          Recife      Nordeste
# 17                Piauí    PI        Teresina      Nordeste
# 18       Rio de Janeiro    RJ  Rio de Janeiro       Sudeste
# 19  Rio Grande do Norte    RN           Natal      Nordeste
# 20    Rio Grande do Sul    RS    Porto Alegre           Sul
# 21             Rondônia    RO     Porto Velho         Norte
# 22              Roraima    RR       Boa Vista         Norte
# 23       Santa Catarina    SC   Florianópolis           Sul
# 24            São Paulo    SP       São Paulo       Sudeste
# 25              Sergipe    SE         Aracaju      Nordeste
# 26            Tocantins    TO          Palmas         Norte

# %%
estados[estados['Sigla']=='SP']['Capital'].iloc[0]
# Out:
# 'São Paulo'
